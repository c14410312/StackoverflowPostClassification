# %% [markdown]
# # Assigning categories to all the posts
# * this will be achieved using the functions created in phase 4 - assigning_java_topic, extracting_keywords
# * the topics will be assigned a unique number from 1-n
# * each post will be assigned a topic number (Foreign Key)
# * add a category key table to postgres DB

# %%
import pandas as pd
df = pd.read_csv('./data/java_questions_including_topics.csv')

# %%
df.Topic.value_counts()
# Out:
# 17.0    658
# 19.0    506
# 15.0    477
# 18.0    380
# 3.0     353
# 5.0     262
# 16.0    218
# 14.0    202
# 12.0    168
# 13.0    161
# 2.0     148
# 6.0     135
# 8.0     117
# 7.0     101
# 21.0     60
# 11.0     59
# 0.0      54
# 4.0      43
# 1.0      40
# 22.0     21
# 23.0     20
# 10.0     11
# 9.0       9
# 20.0      4
# Name: Topic, dtype: int64

# %%
df[df.Topic == 13.0]
# Out:
#             Id                                              Title  \
# 8       107823  Why is my Java program leaking memory when I c...
# 14       33960    How do you get the ethernet address using Java?
# 34      118371  How do you ensure multiple threads can safely ...
# 66      298873  How to detect synchronization violations with ...
# 78      130506  How many threads should I use in my Java program?
# 108     260337  Why does notifyAll() raise IllegalMonitorState...
# 135     319199    Why is Java able to store 0xff000000 as an int?
# 173     430346            Why doesn't Java support unsigned ints?
# 174     671049                  How do you kill a thread in Java?
# 246     877096       How can I pass a parameter to a Java Thread?
# 261     631817                      How to quote "*/" in JavaDocs
# 282     721918  How can I save a PNG with a tEXt or iTXt chunk...
# 294     749641                 How does synchronized work in Java
# ...

# %%
print(df[df['Topic'].isnull()])
# Out:
#             Id                                              Title  \
# 550    1974641                 Why this is not compiling in Java?
# 1119   3450604              Why is there no String.Empty in Java?
# 1868   7382483            How are ArrayLists implemented in Java?
# 2346  10504246  Why does EnumMap<T>.keySet() return a Set<T>()...
# 2386  10607990                 How should I copy Strings in Java?
#
#                                                    Body Tags  \
# 550   <p>If you give</p>\n\n<pre><code>    public cl...
# 1119  <p>I understand that every time I type the str...
# 1868  <p>Did some searching before asking, some not-...
# 2346  <p>I'm writing a program with a lot of enumera...
# 2386  <pre><code>    String s = "hello";\n    String...
#
#                                                    body  Topic
# 550   <p>Variable declarations can only be declared ...    NaN
# 1119  <p><code>String.EMPTY</code> is 12 characters,...    NaN
# ...
