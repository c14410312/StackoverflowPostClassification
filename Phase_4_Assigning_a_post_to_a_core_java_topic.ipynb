# %% [markdown]
# # Create a function to categorise posts based on tags
#
# * Required to categorise the posts into less granular topics based on the tags related to each post
# * Assign a category to posts without any tags

# %% [markdown]
# # Import stopwords

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stopWords = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/dbutler/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# # 1 - Parse core java topics
# * site: http://java.meritcampus.com/core-java-topics
# * extracted the terms from the above website into a file
# * created the function below to create a dictionary storing the core topic along with a unique list of key terms related to that topic

# %%
new_topic = True
java_topic_dict = {}
java_topic = ''
tmp_list = []

with open('./data/java_topics.txt') as file:
    for line in file:   
        #create a new topic
        if line in '\n':
            java_topic_dict[java_topic] = set(tmp_list)
            tmp_list = []
            new_topic = True
            continue
            
        if new_topic:
            #assign the current line to be the java topic
            java_topic = ' '.join(line.split()[1:])
            new_topic = False
            continue
        
        #split each line into individual words and append
        for el in line.split()[1:]:
            #stopword removal
            if el not in stopWords and len(el) > 1:
                tmp_list.append(el.lower().replace('-', ''))

# %%
java_topic_dict.keys()
# Out:
# dict_keys(['Datatypes', 'Variables', 'Operators', 'Control Statements', 'Methods', 'Arrays', 'Classes', 'Inheritance', 'Methods Overiding, Overloading', 'Abstract Class And Methods', 'Interfaces, Packages and Access Control', 'final, static and others', 'Exceptions', 'Multithreaded Programming', 'Generics', 'Strings', 'java.lang', 'Collections Framework', 'Utility Classes', 'Input/Output', 'The Applet Class', 'Swing', 'Servlets'])

# %% [markdown]
# ## Create a list of the topic keys

# %%
java_topic_keys = list(java_topic_dict.keys())

# %% [markdown]
# # 2 - eliminate frequently occuring sub terms across various topics
# * example the word class appears in a wide variety of topics
#
# The function below eliminates all the terms in a given topic that occur in other topics and retains the terms unique to that topic only

# %%
# stores the refined topic terms
new_java_topic_dict = {}

#scan through each topic
for key in java_topic_keys:
    
    #tmp list to hold all the terms related to topic
    tmp_list = []
    for item in java_topic_keys:
        #we do not want to add the terms related to the current topic to the main list
        #when detected move on to next
        if item == key:
            continue
        else:
            #for each term related to the topic append them to the tmp list
            for el in list(java_topic_dict[item]):
                tmp_list.append(el)
    #create a set form the tmp list containing terms from all the topics except the current topic (key)
    #this creates our stop list
    stop_list = set(tmp_list)
    
    #initialise a filtered_list to store unique values for each topic
    filtered_list = []
    for el in list(java_topic_dict[key]):
        #if it doesnt appear in our stop list dont append it
        if el not in stop_list:
            filtered_list.append(el)

    #add the key to the list
    filtered_list.append(key.lower())
    #creates a new list of unique terms related to that topic. 
    new_java_topic_dict[key] = filtered_list

# %% [markdown]
# # 3 - Attempt to categorise posts in the dataset based on their tag values

# %%
import pandas as pd
df = pd.read_csv('./data/filtered_cleaned_posts_no_frameworks_no_alt_lang.csv')

# %%
df.shape
# Out:
# (4212, 5)

# %%
# word2vec function converts the word into a vector
def word2vec(word):
    from collections import Counter
    from math import sqrt

    # count the characters in word
    cw = Counter(word)
    # precomputes a set of the different characters
    sw = set(cw)
    # precomputes the "length" of the word vector
    lw = sqrt(sum(c*c for c in cw.values()))

    # return a tuple
    return cw, sw, lw

# calculates the cosine similarity between 2 vectors i.e. words
def cosdis(v1, v2):
    # which characters are common to the two words?
    common = v1[1].intersection(v2[1])
    # by definition of cosine distance we have
    return sum(v1[0][ch]*v2[0][ch] for ch in common)/v1[2]/v2[2]

# %% [markdown]
# # 4 - function to categorise a post

# %%
'''
    Description:
        takes an argument of a list of tags and checks two things:
        
        1)  checks to see if any of the tags are related directly to a core topic e.g. generics, classes, exceptions
            if the score is greater than 95% then it returns the key that the tag scored greater than 95% against.
        
        2)  If there is no match over 95% for the keys, the tags are then compared to each of the terms in all 
            of the topics, each topics terms are loaded in and the cosine similarity is checked against each word
            the highest scoring word is stored. For example if there are three tags, each tag will be compared to the 
            rest of the terms in a given topic. The highest score for each tag is appended to a total score, 
            this generates a percentage of how likely it is related to that topic. The highest scoring topic is returned
    
    args: tag_list
        list of tags related to a given post
        
'''
def assign_java_topic(tag_list):
    
    #first check if it contains a core topic tag
    for tag in tag_list:
        tag = tag.replace('-', '')
        va = word2vec(tag)
        for jkey in java_topic_keys:
            vb = word2vec(jkey.lower())
            #if the cosine similarity is greater than 95% return that key as the category
            if cosdis(va, vb) > 0.95:
                return jkey, cosdis(va,vb)

    #stores the most likely topic
    max_topic_name = ''
    #holds the max topic score for the set of tags
    max_topic_score = 0

    for key in java_topic_keys:
        #stores the score of the current topic
        topic_score = 0
        #each tag is converted to a vector
        for tag in tag_list:
            tag = tag.replace('-', '')
            va = word2vec(tag)
            max_tag_score = 0

            #for every element in the current topic e.g. classes
            for el in new_java_topic_dict[key]:
                #vb is the current term in the current topic converted to vector format
                vb = word2vec(el)
                #calculate the cosine similarity
                score = cosdis(va,vb)

                #if the score is greater than the current max tag score then 
                # assign this as the new max
                if score > max_tag_score:
                    max_tag_score = score
            #increment the overall topic score using the max tag score
            topic_score += max_tag_score
            
        #check if this is the highest scoring topic score
        if topic_score > max_topic_score:
            max_topic_score = topic_score
            max_topic_name = key
    
    #returns the highest scoring topic along with the score as a percentage. 
    return max_topic_name, max_topic_score/len(tag_list)

# %% [markdown]
# # 5 - Test the function against some posts

# %%
test = df.head(10)

# %%
for index, row in test.iterrows():   
    topic_name, topic_score = assign_java_topic(test.loc[index, 'Tags'].split())
    print(test.loc[index, 'Tags'].split())
    print(topic_name)
    print(topic_score)
    print('\n')
# Out:
# ['exception', 'mocking', 'try-catch']
# Exceptions
# 0.9574271077563381
#
#
# ['generics', 'syntax']
# Generics
# 0.9999999999999999
#
#
# ['-ee', 'jvm', 'out-of-memory', 'heap-memory']
# Classes
# 0.7247445514768732
#
#
# ['string', 'random', 'alphanumeric']
# Strings
# 0.9525793444156805
#
#
# ['class', 'clone']
# Classes
# 0.8590265111456049
#
#
# ['generics']
# Generics
# 0.9999999999999999
#
#
# ['interface', 'static']
# Operators
# 0.8423850737154739
#
#
# ['string']
# Strings
# 0.9525793444156805
#
#
# ['multithreading', 'memory-leaks']
# Multithreaded Programming
# 0.7841429308197335
#
#
# ['arrays', 'data-structures', 'data-manipulation']
# Arrays
# 0.9999999999999999

# %% [markdown]
# # 6 - Assign topic to posts with no tags using the title
# * Using the title - use textblob and POS tagging to extract all adjectives and nouns from a title
# * append these to a list and pass them to the assign_java_topic function

# %%
def extract_title_keywords(title):
    from textblob import TextBlob
    s_list = []
    blob = TextBlob(title)
    for word, pos in blob.tags:
        if pos == 'NN' or pos == 'JJ' or pos == 'VB':
            s_list.append(word)
    return s_list

# %%
s_test = ["How can I make this java generic cast?", "How to convert nanoseconds to seconds using the TimeUnit enum?",
         "How can I sort the keys of a Map in Java?", "How does Java convert int into byte?", 
          "how to convert byte array to string and vice versa ", "How do I make a Class extend Observable when it has extended another class too?",
         "How to check if an IP address is the local host on a multi-homed system?"]
for s in s_test: 
    res = extract_title_keywords(s)
    topic_name, topic_score = assign_java_topic(res)
    print(res)
    print(topic_name)
    print(topic_score)
    print('\n')
# Out:
# ['make', 'java', 'generic', 'cast']
# Collections Framework
# 0.7846088201832161
#
#
# ['convert', 'enum']
# Collections Framework
# 0.8795767165529425
#
#
# ['sort', 'keys']
# java.lang
# 0.7618016810571369
#
#
# ['convert', 'int', 'byte']
# java.lang
# 0.8273206885909709
#
#
# ['convert', 'byte', 'array', 'string', 'vice', 'versa']
# Strings
# 0.9525793444156805
#
#
# ['make', 'extend', 'class']
# Control Statements
# 0.7672497797561304
#
#
# ['check', 'address', 'local', 'host', 'multi-homed', 'system']
# java.lang
# 0.7322116450659335

# %% [markdown]
# # Assign topics to each post in the dataframe
# * if the post has tags available use the tags
# * otherwise, if no tags avaialable use the title

# %%
#store the codes
java_topic_codes = {}
count = 0

for key in java_topic_keys:
    java_topic_codes[key] = count
    count += 1
#sets a default key
java_topic_codes['other'] = count

# %%
java_topic_codes
# Out:
# {'Abstract Class And Methods': 9,
#  'Arrays': 5,
#  'Classes': 6,
#  'Collections Framework': 17,
#  'Control Statements': 3,
#  'Datatypes': 0,
#  'Exceptions': 12,
#  'Generics': 14,
#  'Inheritance': 7,
#  'Input/Output': 19,
#  'Interfaces, Packages and Access Control': 10,
#  'Methods': 4,
#  'Methods Overiding, Overloading': 8,
#  'Multithreaded Programming': 13,
#  'Operators': 2,
#  'Servlets': 22,
#  'Strings': 15,
#  'Swing': 21,
#  'The Applet Class': 20,
#  'Utility Classes': 18,
#  'Variables': 1,
#  'final, static and others': 11,
#  'java.lang': 16,
#  'other': 23}

# %%
# check if tags column empty
df.Tags[df.Tags == "  -7"].count()
# Out:
# 0

# %%
#initialise the topic column
df["Topic"] = None
for index, row in df.iterrows():
    #if tags are not present use the title from the post
    if df.loc[index, "Tags"] == "  " or df.loc[index, "Tags"] in "-8" or df.loc[index, "Tags"] in "-7":
        #extract the keywords from the title
        res = extract_title_keywords(df.loc[index, "Title"])
        if len(res) > 0:
            topic_name, topic_score = assign_java_topic(res)
            df.loc[index, "Topic"] = java_topic_codes[topic_name]
    #otherwise use the tags
    else:
        topic_name, topic_score = assign_java_topic(df.loc[index, "Tags"].split())
        
        if topic_name == '':
            topic_name = "other"
        df.loc[index, "Topic"] = java_topic_codes[topic_name]

# %%
df[df.Topic == 4]
# Out:
#             Id                                              Title  \
# 17      189787   How to format methods with large parameter lists
# 58       21817  Why can't I declare static methods in an inter...
# 260     576918  How do I intercept a method invocation with st...
# 264     610458  Why isn't calling a static method by way of an...
# 542    2211002                           Why not abstract fields?
# 554    1411612  How to test for equality of complex object gra...
# 621    1924253  How to determine by reflection if a Method ret...
# 671    2315445  How to quickly determine if a method is overri...
# 751    2563791  Why does Java's invokevirtual need to resolve ...
# 767    2636660  why no replace() method defined on the Set int...
# 799    1932399  Is it a bad idea to declare a final static met...
# 890    3027273  How to store and load keys using java.security...
# 1295   3804442  why `java.lang.SecurityException: Prohibited p...
# 1343   4018488  How can I convert from Gregorian Calendar to U...
# 1401   4952856  How to write Java function that returns values...
# 1405   4964628  Why is it wrong to use numbers in Java method ...
# 1418   4899559     How does join() work? (Multithreading in Java)
# 1423   3704747  How to write unit test for "InterruptedException"
# 1465   3893644        Why is Java labeled as a "secure" language?
# 1699   5529532                   How to get a test resource file?
# 1827   7058621  How To Check If A Method Exists At Runtime In ...
# 1981   6138666                      How to unit test constructors
# 1983   7228590  How to check if a parameter of the current met...
# 2027   7440946  How to write a UT to mock an internal object i...
# 2050   7607353  How to create Java method that accepts variabl...
# 2099   8838339  Why is it not allowed in Java to overload Foo(...
# 2234   9899657                 How should you approach recursion?
# 2269   9244185                    Why is MouseAdapter an adapter?
# 2403  10742322  How to rewrite Ackermann function in non-recur...
# 2473  12063292  How to pass a static class as an argument in Java
# 2625  12780779  Why Java allows increasing the visibility of p...
# 2699  13314316  Why is the return type of method not included ...
# 2733  13915143           Why is an explicit cast not needed here?
# 2831  15281904  Why does this Java method appear to have two r...
# 2991  17256627          How to enforce sequence in function calls
# 3124  14432114            How to return a boolean method in java?
# 3181  19406290        How to make n nested for loops recursively?
# 3475  18331350  How to force implementation of a method in sub...
# 3513  18540619  Why doesn't the JVM simply terminate instead o...
# 3526  28064692  Why override equals instead of using another m...
# 3675  30402169        Why is a static method considered a method?
# 3810  34500585  How can I improve the efficiency and/or perfor...
# 3871  34202701            How to stop a ScheduledExecutorService?
#
#                                                    Body  \
# 17    <p>I have never seen a way to do this nicely, ...
# 58    <p>The topic says the most of it - what is the...
# 260   <p>I want to intercept all method invocations ...
# 264   <p>I'm sure you all know the behaviour I mean ...
# 542   <p>Why can't Java classes have abstract fields...
# 554   <p>Say I have a unit test that wants to compar...
# 621   <p>I have a <code>java.lang.reflect.Method</co...
# 671   <p>There is a possible optimization I could ap...
# 751   <p>Consider this simple Java class:</p>\n\n<pr...
# 767   <p>Currently I have to write the following to ...
# 799   <p>I understand that in this code:</p>\n\n<pre...
# 890   <p>After creating secret keys, how do I store ...
# 1295  <p>I created a class "String" and placed that ...
# 1343  <p>I am in need of a method to convert Gregori...
# 1401  <p>For example, I want to create a function th...
# 1405  <p>Sometime ago, I remember being told not to ...
# 1418  <p>I'm preparing for an exam and after going o...
# 1423  <p>In attempts of 100% code coverage, I came a...
# 1465  <p>I guess this is a general question, but I a...
# 1699  <p>In a unit test I need to import a csv file....
# 1827  <p>How would one go about checking to see if a...
# 1981  <p>I have a class I am adding unit tests to. T...
# 1983  <p>Consider this code:</p>\n\n<pre><code>publi...
# 2027  <p>For example , I have a java class as below....
# 2050  <p>For example, Java's own <code>String.format...
# 2099  <p>I was wondering why it is not allowed in Ja...
# 2234  <p>I am currently studying recursion in school...
# 2269  <p>The name (and javadocs) imply that <code>Mo...
# 2403  <p>I have function</p>\n\n<pre><code>public st...
# 2473  <p>I have a base class called "Entity" which h...
# 2625  <pre><code>abstract class Base{\n      protect...
# 2699  <p>Why does return type of method not included...
# 2733  <pre><code>class MyClass {\n    void myMethod(...
# 2831  <pre><code>public &lt;E extends Foo&gt; List&l...
# 2991  <p>Let's say I want to design a class whose cl...
# 3124  <p>I need help on how to return a boolean meth...
# 3181  <p>I have a method that must do the following:...
# 3475  <p>I want to force subclass to implement an im...
# 3513  <p>If catching an <code>OutOfMemoryError</code...
# 3526  <p>This seems like a silly question but why do...
# 3675  <p>I'm writing an explanation for some code fo...
# 3810  <p>I'm building a classifier which has to read...
# 3871  <p>The program finishes after nine prints:</p>...
#
#                                                    Tags  \
# 17                                 formatting  methods
# 58                          interface  methods  static
# 260                                reflection  methods
# 264                                    static  methods
# 542                           methods  field  abstract
# 554                                       unit-testing
# 621                                reflection  methods
# 671               oop  optimization  methods  override
# 751                       jvm  methods  virtual-method
# 767
# 799                             static  methods  final
# 890                                           security
# 1295                                          security
# 1343       methods  gregorian-calendar  unix-timestamp
# 1401                       methods  method-overloading
# 1405                                methods  standards
# 1418       multithreading  join  methods  synchronized
# 1423                                      unit-testing
# 1465                                          security
# 1699               testing  resources  maven  surefire
# 1827                        methods  try-catch  exists
# 1981                                      unit-testing
# 1983           class  reflection  methods  annotations
# 2027                                      unit-testing
# 2050             function  methods  method-overloading
# 2099     methods  parameters  arguments  language-sp...
# 2234                                         recursion
# 2269                                   design-patterns
# 2403                                     non-recursive
# 2473                                   design-patterns
# 2625                                   design-patterns
# 2699
# 2733                     methods  casting  return-type
# 2831                                           methods
# 2991                                   design-patterns
# 3124                        function  methods  boolean
# 3181                                         recursion
# 3475              class  methods  abstract  implements
# 3513
# 3526
# 3675      methods  static  static-methods  terminology
# 3810     performance  methods  classification  word-...
# 3871                                   executorservice
#
#                                                    body Topic
# 17    <p>A large set of parameters like this is ofte...     4
# 58    <p>There are a few issues at play here.  The f...     4
# 260   <p>As you note, you cannot use JDK dynamic pro...     4
# 264   <p>Basically I believe the Java designers made...     4
# 542   <p>You can do what you described by having a f...     4
# 554   <p>What you could do is render each object to ...     4
# 621   <pre><code>if( method.getReturnType().equals(V...     4
# 671   <p>I wouldn't do this. It violates encapsulati...     4
# 751   <p>It is all about performance. When by figuri...     4
# 767   <p>A Set is a data structure made to avoid dup...     4
# 799   <p>I don't consider it's bad practice to mark ...     4
# 890   <p>Storing:</p>\n\n<pre><code>KeyStore ks = Ke...     4
# 1295  <p>User code is <em>never</em> allowed to put ...     4
# 1343  <p>The methods <code>getTimeInMillis()</code> ...     4
# 1401  <p>No, you can't do that in Java.</p>\n\n<p>Yo...     4
# 1405  <p>The standard Java class library is full of ...     4
# 1418  <p><strong>There is something wrong with the a...     4
# 1423  <p>Right before invoking <code>addMessage()</c...     4
# 1465  <p>IMHO, that's a very misleading statement. I...     4
# 1699  <p>Probably just useful if you have the file a...     4
# 1827  <p>I assume that you want to check the method ...     4
# 1981  <p>It looks like you've got a canonical way of...     4
# 1983  <p>The outer for loop</p>\n\n<pre><code>for (A...     4
# 2027  <p>If you can't change the code, you can use P...     4
# 2050  <p>You could write a convenience method:</p>\n...     4
# 2099  <p>This <a href="http://java.sun.com/docs/book...     4
# 2234  <blockquote>\n  <p>how you can tackle recursio...     4
# 2269  <p><code>MouseAdapter</code> first appeared in...     4
# 2403  <p>Not quite O(1) but definitely non-recursive...     4
# 2473  <p>Use a <a href="http://en.wikipedia.org/wiki...     4
# 2625  <p>Why decreasing visibility is not allowed is...     4
# 2699  <p>This is done because the compiler would not...     4
# 2733  <p>Java supports narrowing in this case. From ...     4
# 2831  <p>No, you don't have two return types.It's a ...     4
# 2991  <p>You might be interested in the <a href="htt...     4
# 3124  <p>You're allowed to have more than one <code>...     4
# 3181  <p>Yes. This can be performed by recursive pro...     4
# 3475  <p>You can not force a subclass to override a ...     4
# 3513  <p>Because there is no single standard way to ...     4
# 3526  <blockquote>\n  <p>This seems like a silly que...     4
# 3675  <p>This quote from <a href="http://docs.oracle...     4
# 3810  <p>Your method has <code>O(n*m)</code> run tim...     4
# 3871  <p>The issue you have is that the scheduler ke...     4

# %%
df.to_csv("./data/java_questions_including_topics.csv", index=False)

# %%
for key in java_topic_keys:
    print(key)
# Out:
# Datatypes
# Variables
# Operators
# Control Statements
# Methods
# Arrays
# Classes
# Inheritance
# Methods Overiding, Overloading
# Abstract Class And Methods
# Interfaces, Packages and Access Control
# final, static and others
# Exceptions
# Multithreaded Programming
# Generics
# Strings
# java.lang
# Collections Framework
# Utility Classes
# Input/Output
# The Applet Class
# Swing
# Servlets
