# %% [markdown]
# # Classifying the Java Posts from SO
#
# * Dylan Butler
# * 26/02/18
#
# ## Overview
# This notebook will document the process of classifying new data which contains all the Java tagged how-to and why questions from stackoverflow into two categories: OK (1) for quizzes or NOT OK (0) for quizzes. A pipeline of processes will be created to automate preprocessing the raw data, inserting it into the model and storing the OK posts for the application to work off.
#
# ## Process
# 1. Load the data into a dataframe
# 2. Preprocess the data:
#     * Clean the tags
#     * Chunk the title and tags into a single column
# 3. Passing each instance into the trained model and labelling with 1(OK) or 0 (NOT OK)
# 4. Discard all NOT OK posts
# 5. Save postID, Title, Tags and Accepted Answer to a PostgreSQL DB

# %% [markdown]
# # 1) Load the data

# %%
import pandas as pd
df = pd.read_csv('./data/StackoverflowCompleteDS_JAVA.csv')

# %% [markdown]
# # 2) Preprocess the data

# %%
df = df[['Id', 'Title','Body','Tags', 'body']]

# %%
df.head()
# Out:
#       Id                                              Title  \
# 0   5328  Why can't I use a try block around my super() ...
# 1  15690         How do you begin designing a large system?
# 2  24866  Is it essential that I use libraries to manipu...
# 3  25449           How to create a pluginable Java program?
# 4  24991  Why can't I explicitly pass the type argument ...
#
#                                                 Body  \
# 0  <p>So, in Java, the first line of your constru...
# 1  <p>It's been mentioned to me that I'll be the ...
# 2  <p>I am using Java back end for creating an XM...
# 3  <p>I want to create a Java program that can be...
# 4  <p>I have defined a Java function:</p>\n\n<pre...
#
#                                     Tags  \
# 0  <java><exception><mocking><try-catch>
# 1      <java><oop><design><architecture>
# 2                            <java><xml>
# 3   <java><plugins><plugin-architecture>
# 4               <java><generics><syntax>
#
#                                                 body
# 0  <p>Unfortunately, compilers can't work on theo...
# 1  <p>Do you know much about OOP?  If so, look in...
# 2  <p>It's not essential, but advisable. However,...
# 3  <p>I've done this for software I've written in...
# 4  <p>When the java compiler cannot infer the par...

# %% [markdown]
# ## a) Clean the tags

# %%
def clean_tags(raw_tags):
    cleaned_tags = raw_tags.replace('>', " ").replace('<', " ").replace('java', '')
    return cleaned_tags

for index, row in df.iterrows():
    cleaned_tags = clean_tags(df.loc[index, 'Tags'])
    df.loc[index, 'Tags'] = cleaned_tags

# %% [markdown]
# ## b) Chunking the title and tags per post

# %%
df['title_tag_chunk'] = df[df.columns[1:3]].apply(lambda x: ','.join(x),axis=1)

# %% [markdown]
# # 3) Load the Trained NaiveBayes Model and Filter Dataset

# %%
import pickle
trained_NB_model = pickle.load(open('./models/multinomialnb_classifier_ngrams_title_tag.sav', 'rb'))

# %% [markdown]
# ## a) Test out approach on sample of data set and analyse results

# %%
import numpy as np

# %%
tmp_df = df[50:100]

# %%
test_list = list(tmp_df['title_tag_chunk'])

# %%
len(trained_NB_model.predict(test_list))
# Out:
# 50

# %%
for l in test_list:
    prediction = trained_NB_model.predict([l])
    print("Question: {}\n Prediciton: {}\n".format(l, prediction))
# Out:
# Question: How to convert a Reader to InputStream and a Writer to OutputStream?,<p>Is there an easy way to avoid dealing with text encoding problems?</p>
#
#  Prediciton: [1]
#
# Question: Why am I getting a ClassCastException when generating javadocs?,<p>I'm using ant to generate javadocs, but get this exception over and over - why?</p>
#
# <p>I'm using JDK version <strong>1.6.0_06</strong>.</p>
#
# <pre><code>[javadoc] java.lang.ClassCastException: com.sun.tools.javadoc.ClassDocImpl cannot be cast to com.sun.javadoc.AnnotationTypeDoc
#   [javadoc]     at com.sun.tools.javadoc.AnnotationDescImpl.annotationType(AnnotationDescImpl.java:46)
#   [javadoc]     at com.sun.tools.doclets.formats.html.HtmlDocletWriter.getAnnotations(HtmlDocletWriter.java:1739)
#   [javadoc]     at com.sun.tools.doclets.formats.html.HtmlDocletWriter.writeAnnotationInfo(HtmlDocletWriter.java:1713)
#   [javadoc]     at com.sun.tools.doclets.formats.html.HtmlDocletWriter.writeAnnotationInfo(HtmlDocletWriter.java:1702)
#   [javadoc]     at com.sun.tools.doclets.formats.html.HtmlDocletWriter.writeAnnotationInfo(HtmlDocletWriter.java:1681)
#   [javadoc]     at com.sun.tools.doclets.formats.html.FieldWriterImpl.writeSignature(FieldWriterImpl.java:130)
#   [javadoc]     at com.sun.tools.doclets.internal.toolkit.builders.FieldBuilder.buildSignature(FieldBuilder.java:184)
#   [javadoc]     at sun.reflect.GeneratedMethodAccessor8.invoke(Unknown Source)
#   [javadoc]     at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:25)
#   [javadoc]     at java.lang.reflect.Method.invoke(Method.java:597)
#   [javadoc]     at com.sun.tools.doclets.internal.toolkit.builders.FieldBuilder.invokeMethod(FieldBuilder.java:114)
#   [javadoc]     at com.sun.tools.doclets.internal.toolkit.builders.AbstractBuilder.build(AbstractBuilder.java:90)
#   [javadoc]     at com.sun.tools.doclets.internal.toolkit.builders.AbstractMemberBuilder.build(AbstractMemberBuilder.java:56)
#   [javadoc]     at com.sun.tools.doclets.internal.toolkit.builders.FieldBuilder.buildFieldDoc(FieldBuilder.java:158)
#   [javadoc]     at sun.reflect.GeneratedMethodAccessor51.invoke(Unknown Source)
#   [javadoc]     at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:25)
#   [javadoc]     at java.lang.reflect.Method.invoke(Method.java:597)
#   [javadoc]     at com.sun.tools.doclets.internal.toolkit.builders.FieldBuilder.invokeMethod(FieldBuilder.java:114)
#   [javadoc]     at com.sun.tools.doclets.internal.toolkit.builders.AbstractBuilder.build(AbstractBuilder.java:90)
#   [javadoc]     at com.sun.tools.doclets.internal.toolkit.builders.AbstractMemberBuilder.build(AbstractMemberBuilder.java:56)
#   [javadoc]     at com.sun.tools.doclets.internal.toolkit.builders.ClassBuilder.buildFieldDetails(ClassBuilder.java:301)
#   [javadoc]     at sun.reflect.GeneratedMethodAccessor43.invoke(Unknown Source)
#   [javadoc]     at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:25)
#   [javadoc]     at java.lang.reflect.Method.invoke(Method.java:597)
#   [javadoc]     at com.sun.tools.doclets.internal.toolkit.builders.ClassBuilder.invokeMethod(ClassBuilder.java:101)
#   [javadoc]     at com.sun.tools.doclets.internal.toolkit.builders.AbstractBuilder.build(AbstractBuilder.java:90)
#   [javadoc]     at com.sun.tools.doclets.internal.toolkit.builders.ClassBuilder.buildClassDoc(ClassBuilder.java:124)
#   [javadoc]     at sun.reflect.GeneratedMethodAccessor19.invoke(Unknown Source)
#   [javadoc]     at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:25)
#   [javadoc]     at java.lang.reflect.Method.invoke(Method.java:597)
#   [javadoc]     at com.sun.tools.doclets.internal.toolkit.builders.ClassBuilder.invokeMethod(ClassBuilder.java:101)
#   [javadoc]     at com.sun.tools.doclets.internal.toolkit.builders.AbstractBuilder.build(AbstractBuilder.java:90)
#   [javadoc]     at com.sun.tools.doclets.internal.toolkit.builders.ClassBuilder.build(ClassBuilder.java:108)
#   [javadoc]     at com.sun.tools.doclets.formats.html.HtmlDoclet.generateClassFiles(HtmlDoclet.java:155)
#   [javadoc]     at com.sun.tools.doclets.internal.toolkit.AbstractDoclet.generateClassFiles(AbstractDoclet.java:164)
#   [javadoc]     at com.sun.tools.doclets.internal.toolkit.AbstractDoclet.startGeneration(AbstractDoclet.java:106)
#   [javadoc]     at com.sun.tools.doclets.internal.toolkit.AbstractDoclet.start(AbstractDoclet.java:64)
#   [javadoc]     at com.sun.tools.doclets.formats.html.HtmlDoclet.start(HtmlDoclet.java:42)
#   [javadoc]     at com.sun.tools.doclets.standard.Standard.start(Standard.java:23)
#   [javadoc]     at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
#   [javadoc]     at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:39)
#   [javadoc]     at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:25)
#   [javadoc]     at java.lang.reflect.Method.invoke(Method.java:597)
#   [javadoc]     at com.sun.tools.javadoc.DocletInvoker.invoke(DocletInvoker.java:215)
#   [javadoc]     at com.sun.tools.javadoc.DocletInvoker.start(DocletInvoker.java:91)
#   [javadoc]     at com.sun.tools.javadoc.Start.parseAndExecute(Start.java:340)
#   [javadoc]     at com.sun.tools.javadoc.Start.begin(Start.java:128)
#   [javadoc]     at com.sun.tools.javadoc.Main.execute(Main.java:41)
#   [javadoc]     at com.sun.tools.javadoc.Main.main(Main.java:31)
# </code></pre>
#
#  Prediciton: [0]
#
# Question: How to fetch HTML in Java,<p>Without the use of any external library, what is the simplest way to fetch a website's HTML content into a String?</p>
#
#  Prediciton: [0]
#
# Question: How do I configure and communicate with a serial port?,<p>I need to send and receive data over serial connections (RS-232 and RS-422).</p>
#
# <p>How do I set up and communicate with such a connection?  How do I figure out what the configuration settings (e.g. baud rate) should be and how do I set them?</p>
#
# <p>In particular I am looking to do this in Java, C/C++, or one of the major Unix shells but I also have some interest in serial programming using Windows/Hyperterminal.</p>
#
#  Prediciton: [0]
#
# Question: How do I split strings in J2ME?,<p>How do I split strings in J2ME in an effective way?</p>
#
# <p>There is a <a href="http://download.oracle.com/javase/1.4.2/docs/api/java/util/StringTokenizer.html" rel="noreferrer"><code>StringTokenizer</code></a> or <a href="http://download.oracle.com/javase/1.5.0/docs/api/java/lang/String.html#split%28java.lang.String%29" rel="noreferrer"><code>String.split(String regex)</code></a> in the standard edition (J2SE), but they are absent in the micro edition (J2ME, MIDP).</p>
#
#  Prediciton: [0]
#
# Question: How to set a long Java classpath in Windows?,<p>I'm trying to run a particular JUnit test by hand on a Windows XP command line, which has an unusually high number of elements in the class path.  I've tried several variations, such as:</p>
#
# <pre><code>set CLASS_PATH=C:\path\a\b\c;C:\path\e\f\g;....
# set CLASS_PATH=%CLASS_PATH%;C:\path2\a\b\c;C:\path2\e\f\g;....
# ...
# C:\apps\jdk1.6.0_07\bin\java.exe -client oracle.jdevimpl.junit.runner.TestRunner com.myco.myClass.MyTest testMethod
# </code></pre>
#
# <p>(Other variations are setting the classpath all on one line, setting the classpath via -classpath as an argument to java").  It always comes down to the console throwing up it's hands with this error:</p>
#
# <pre><code>The input line is too long.
# The syntax of the command is incorrect.
# </code></pre>
#
# <p>This is a JUnit test testing a rather large existing legacy project, so no suggestions about rearranging my directory structure to something more reasonable, those types of solutions are out for now.  I was just trying to gen up a quick test against this project and run it on the command line, and the console is stonewalling me.  Help!</p>
#
#  Prediciton: [0]
#
# Question: Why doesn't Java autoboxing extend to method invocations of methods of the autoboxed types?,<p>I want to convert a primitive to a string, and I tried:</p>
#
# <pre><code>myInt.toString();
# </code></pre>
#
# <p>This fails with the error:</p>
#
# <pre><code>int cannot be dereferenced
# </code></pre>
#
# <p>Now, I get that primitives are not reference types (ie, not an Object) and so cannot have methods.  However, Java 5 introduced autoboxing and unboxing (a la C#... which I never liked in C#, but that's beside the point).  So with autoboxing, I would expect the above to convert myInt to an Integer and then call toString() on that.</p>
#
# <p>Furthermore, I believe C# allows such a call, unless I remember incorrectly.  Is this just an unfortunate shortcoming of Java's autoboxing/unboxing specification, or is there a good reason for this?</p>
#
#  Prediciton: [1]
#
# Question: How do I open the default mail program with a Subject and Body in a cross-platform way?,<p>How do I open the default mail program with a Subject and Body in a cross-platform way?</p>
#
# <p>Unfortunately, this is for a a client app written in Java, not a website.</p>
#
# <p>I would like this to work in a cross-platform way (which means Windows and Mac, sorry Linux). I am happy to execute a VBScript in Windows, or AppleScript in OS X. But I have no idea what those scripts should contain. I would love to execute the user's default program vs. just searching for Outlook or whatever.</p>
#
# <p>In OS X, I have tried executing the command:</p>
#
# <pre><code>open mailto:?subject=MySubject&amp;body=TheBody
# </code></pre>
#
# <p>URL escaping is needed to replace spaces with <code>%20</code>.</p>
#
# <p><strong>Updated</strong> On Windows, you have to play all sorts of games to get <code>start</code> to run correctly. Here is the proper Java incantation:</p>
#
# <pre><code>class Win32 extends OS {
#     public void email(String subject, String body) throws Exception {
#         String cmd = "cmd.exe /c start \"\" \"" + formatMailto(subject, body) + "\"";
#         Runtime.getRuntime().exec(cmd);
#     }
# }
# </code></pre>
#
#  Prediciton: [0]
#
# Question: Why do you not explicitly call finalize() or start the garbage collector?,<p>After reading <a href="https://stackoverflow.com/questions/28832/java-and-manually-executing-finalize">this question</a>, I was reminded of when I was taught Java and told never to call finalize() or run the garbage collector because "it's a big black box that you never need to worry about". Can someone boil the reasoning for this down to a few sentences? I'm sure I could read a technical report from Sun on this matter, but I think a nice, short, simple answer would satisfy my curiosity.</p>
#
#  Prediciton: [1]
#
# Question: How do I clone a generic List in Java?,<p>I have an <code>ArrayList&lt;String&gt;</code> that I'd like to return a copy of.  <code>ArrayList</code> has a clone method has the following signature:</p>
#
# <pre><code>public Object clone()
# </code></pre>
#
# <p>After I call this method, how do I cast the returned Object back to <code>ArrayList&lt;String&gt;</code>?</p>
#
#  Prediciton: [1]
#
# Question: How do you crash a JVM?,<p>I was reading a book on programming skills wherein the author asks the interviewee, "How do you crash a JVM?" I thought that you could do so by writing an infinite for-loop that would eventually use up all the memory.</p>
#
# <p>Anybody has any idea?</p>
#
#  Prediciton: [0]
#
# Question: How do I identify immutable objects in Java,<p>In my code, I am creating a collection of objects which will be accessed by various threads in a fashion that is only safe if the objects are immutable. When an attempt is made to insert a new object into my collection, I want to test to see if it is immutable (if not, I'll throw an exception).</p>
#
# <p>One thing I can do is to check a few well-known immutable types:</p>
#
# <pre><code>private static final Set&lt;Class&gt; knownImmutables = new HashSet&lt;Class&gt;(Arrays.asList(
#         String.class, Byte.class, Short.class, Integer.class, Long.class,
#         Float.class, Double.class, Boolean.class, BigInteger.class, BigDecimal.class
# ));
#
# ...
#
# public static boolean isImmutable(Object o) {
#     return knownImmutables.contains(o.getClass());
# }
# </code></pre>
#
# <p>This actually gets me 90% of the way, but sometimes my users will want to create simple immutable types of their own:</p>
#
# <pre><code>public class ImmutableRectangle {
#     private final int width;
#     private final int height;
#     public ImmutableRectangle(int width, int height) {
#         this.width = width;
#         this.height = height;
#     }
#     public int getWidth() { return width; }
#     public int getHeight() { return height; }
# }
# </code></pre>
#
# <p>Is there some way (perhaps using reflection) that I could reliably detect whether a class is immutable? False positives (thinking it's immutable when it isn't) are not acceptable but false negatives (thinking it's mutable when it isn't) are.</p>
#
# <p><strong>Edited to add:</strong> Thanks for the insightful and helpful answers. As some of the answers pointed out, I neglected to define my security objectives. The threat here is clueless developers -- this is a piece of framework code that will be used by large numbers of people who know next-to-nothing about threading and won't be reading the documentation. I do NOT need to defend against malicious developers -- anyone clever enough to <a href="http://directwebremoting.org/blog/joe/2005/05/26/1117108773674.html" rel="noreferrer">mutate a String</a> or perform other shenanigans will also be smart enough to know it's not safe in this case. Static analysis of the codebase IS an option, so long as it is automated, but code reviews cannot be counted on because there is no guarantee every review will have threading-savvy reviewers.</p>
#
#  Prediciton: [1]
#
# Question: How Popular is the Seam Framework,<p>I'm using JBoss Seam Framework, but it's seems to me isn't very popular among java developers.
# I want to know how many java programmers here are using it, and in what kind of projects.
# Is as good as django, or RoR?</p>
#
#  Prediciton: [0]
#
# Question: How to control the capitalization of month and day names returned by DateFormat?,<p>Here is a quick test program:</p>
#
# <pre><code>    public static void main( String[] args )
# {
#     Date date = Calendar.getInstance().getTime();
#
#     System.out.println("Months:");
#     printDate( "MMMM", "en", date );
#     printDate( "MMMM", "es", date );
#     printDate( "MMMM", "fr", date );
#     printDate( "MMMM", "de", date );
#
#     System.out.println("Days:");
#     printDate( "EEEE", "en", date );
#     printDate( "EEEE", "es", date );
#     printDate( "EEEE", "fr", date );
#     printDate( "EEEE", "de", date );
#
# }
#
# public static void printDate( String format, String locale, Date date )
# {
#     System.out.println( locale + ": " + (new SimpleDateFormat( format, new Locale( locale ) )).format( date ) );
# }
# </code></pre>
#
# <p>The output is:</p>
#
# <p><code>
# Months:
# en: September
# es: septiembre
# fr: septembre
# de: September
# Days:
# en: Monday
# es: lunes
# fr: lundi
# de: Montag</code></p>
#
# <p>How can I control the capitalization of the names. For some reason the Spanish and French always seem to return names that start with a lowercase letter.</p>
#
#  Prediciton: [1]
#
# Question: How do you get the length of a list in the JSF expression language?,<p>How would I get the length of an <code>ArrayList</code> using a JSF EL expression? </p>
#
# <pre><code>#{MyBean.somelist.length}
# </code></pre>
#
# <p>does not work.</p>
#
#  Prediciton: [0]
#
# Question: How do I format a number in Java?,<p>How do I format a number in Java?<br>
# What are the "Best Practices"?</p>
#
# <p>Will I need to round a number before I format it?</p>
#
# <blockquote>
#   <p><code>32.302342342342343</code> => <code>32.30</code></p>
#
#   <p><code>.7323</code> => <code>0.73</code></p>
# </blockquote>
#
# <p>etc.</p>
#
#  Prediciton: [1]
#
# Question: How to instantiate a Java array given an array type at runtime?,<p>In the Java collections framework, the Collection interface declares the following method:</p>
#
# <blockquote>
#   <p><a href="http://java.sun.com/javase/6/docs/api/java/util/Collection.html#toArray&#40;T[]&#41;" rel="noreferrer"><code>&lt;T&gt; T[] toArray(T[] a)</code></a></p>
#
#   <p>Returns an array containing all of the elements in this collection; the runtime type of the returned array is that of the specified array. If the collection fits in the specified array, it is returned therein. Otherwise, a new array is allocated with the runtime type of the specified array and the size of this collection.</p>
# </blockquote>
#
# <p>If you wanted to implement this method, how would you create an array of the type of <strong>a</strong>, known only at runtime?</p>
#
#  Prediciton: [1]
#
# Question: How do you keep the machine awake?,<p>I have a piece of server-ish software written in Java to run on Windows and OS X. (It is not running on a server, but just a normal user's PC - something like a torrent client.) I would like the software to signal to the OS to keep the machine awake (prevent it from going into sleep mode) while it is active.</p>
#
# <p>Of course I don't expect there to be a cross platform solution, but I would love to have some very minimal C programs/scripts that my app can spawn to inform the OS to stay awake.</p>
#
# <p>Any ideas?</p>
#
#  Prediciton: [0]
#
# Question: Why doesn't Java offer operator overloading?,<p>Coming from C++ to Java, the obvious unanswered question is why didn't Java include operator overloading?</p>
#
# <p>Isn't <code>Complex a, b, c; a = b + c;</code> much simpler than <code>Complex a, b, c; a=b.add(c);</code>?</p>
#
# <p>Is there a known reason for this, valid arguments for <em>not</em> allowing operator overloading? Is the reason arbitrary, or lost to time?</p>
#
#  Prediciton: [1]
#
# Question: How to create J2ME midlets for Nokia using Eclipse,<p>Nokia has stopped offering its Developer's Suite, relying on other IDEs, including Eclipse. Meanwhile, Nokia changed its own development tools again and EclipseMe has also changed. This leaves most documentation irrelevant. </p>
#
# <p>I want to know what does it take to make a simple Hello-World?</p>
#
# <p>(I already found out myself, so this is a Q&amp;A for other people to use)</p>
#
#  Prediciton: [0]
#
# Question: How can I set a timeout against a BufferedReader based upon a URLConnection in Java?,<p><strong>I want to read the contents of a URL but don't want to "hang" if the URL is unresponsive.  I've created a BufferedReader using the URL...</strong></p>
#
# <pre><code>URL theURL = new URL(url);
# URLConnection urlConn = theURL.openConnection();
# urlConn.setDoOutput(true);
# BufferedReader urlReader = new BufferedReader(newInputStreamReader(urlConn.getInputStream()));
# </code></pre>
#
# <p><strong>...and then begun the loop to read the contents...</strong></p>
#
# <pre><code>do
#     {
#     buf = urlReader.readLine();
#     if (buf != null)
#         {
#         resultBuffer.append(buf);
#         resultBuffer.append("\n");
#         }
#     }
# while (buf != null);
# </code></pre>
#
# <p><strong>...but if the read hangs then the application hangs.</strong></p>
#
# <p><strong>Is there a way, without grinding the code down to the socket level, to "time out" the read if necessary?</strong></p>
#
#  Prediciton: [1]
#
# Question: How can I determine the IP of my router/gateway in Java?,<p>How can I determine the IP of my router/gateway in Java? I can get my IP easily enough. I can get my internet IP using a service on a website. But how can I determine my gateway's IP?</p>
#
# <p>This is somewhat easy in .NET if you know your way around. But how do you do it in Java?</p>
#
#  Prediciton: [1]
#
# Question: How do you create a PDF from XML in Java?,<p>At the moment, I'm creating an XML file in Java and displaying it in a JSP page by transforming it with XSL/XSLT. Now I need to take that XML file and display the same information in a PDF. Is there a way I can do this by using some kind of XSL file?</p>
#
# <p>I've seen the <a href="http://www.lowagie.com/iText/" rel="noreferrer">iText</a> Java-PDF library, but I can't find any way to use it with XML and a stylesheet.</p>
#
# <p>Any assistance would be much appreciated. Thanks in advance!</p>
#
#  Prediciton: [0]
#
# Question: How do I in java add a stacktrace to my debugging printout,<p>What's the easiest way to print a stacktrace from a debugging printout? Often during testing you would like to know the callstack leading up to the situation provoking a debug message.</p>
#
#  Prediciton: [0]
#
# Question: Is it safe to generally assume that toString() has a low cost?,<p>Do you generally assume that toString() on any given object has a low cost (i.e. for logging)?  I do.  Is that assumption valid?  If it has a high cost should that normally be changed?  What are valid reasons to make a toString() method with a high cost?  The only time that I get concerned about toString costs is when I know that it is on some sort of collection with many members.
# From: <a href="http://jamesjava.blogspot.com/2007/08/tostring-cost.html" rel="noreferrer">http://jamesjava.blogspot.com/2007/08/tostring-cost.html</a></p>
#
# <p>Update: Another way to put it is: Do you usually look into the cost of calling toString on any given class before calling it?</p>
#
#  Prediciton: [1]
#
# Question: How do I add a MIME type to .htaccess?,<p>I would like to add the following MIME type to a site run by <code>Apache</code>:</p>
#
# <pre><code>&lt;mime-mapping&gt;
#   &lt;extension&gt;jnlp&lt;/extension&gt;
#   &lt;mime-type&gt;application/x-java-jnlp-file&lt;/mime-type&gt;
# &lt;/mime-mapping&gt;
# </code></pre>
#
# <p><strong>That is the Tomcat format.</strong></p>
#
# <p>I'm on a shared host, so I can only create an <code>.htaccess</code> file. Would someone please specify the complete contents of such a file?</p>
#
#  Prediciton: [0]
#
# Question: How do you query object collections in Java (Criteria/SQL-like)?,<p>Suppose you have a collection of a few hundred in-memory objects and you need to query this List to return objects matching some SQL or Criteria like query. For example, you might have a List of Car objects and you want to return all cars made during the 1960s, with a license plate that starts with AZ, ordered by the name of the car model. </p>
#
# <p>I know about <a href="http://josql.sourceforge.net/" rel="noreferrer">JoSQL</a>, has anyone used this, or have any experience with other/homegrown solutions?</p>
#
#  Prediciton: [0]
#
# Question: How much business logic should Value objects contain?,<p>One mentor I respect suggests that a simple bean is a waste of time - that value objects 'MUST' contain some business logic to be useful. </p>
#
# <p>Another says such code is difficult to maintain and that all business logic must be externalized. </p>
#
# <p>I realize this question is subjective. Asking anyway - want to know answers from more perspectives.</p>
#
#  Prediciton: [0]
#
# Question: How to determine whether a character is a letter in Java?,<p>How do you check if a one-character String is a letter - including any letters with accents?</p>
#
# <p>I had to work this out recently, so I'll answer it myself, after the recent VB6 question reminded me.</p>
#
#  Prediciton: [1]
#
# Question: How can a Java program get its own process ID?,<p>How do I get the id of my Java process? </p>
#
# <p>I know there are several platform-dependent hacks, but I would prefer a more generic solution.</p>
#
#  Prediciton: [1]
#
# Question: How do you maintain java webapps in different staging environments?,<p>You might have a set of properties that is used on the developer machine, which varies from developer to developer, another set for a staging environment, and yet another for the production environment. </p>
#
# <p>In a Spring application you may also have beans that you want to load in a local environment but not in a production environment, and vice versa. </p>
#
# <p>How do you handle this? Do you use separate files, ant/maven resource filtering or other approaches? </p>
#
#  Prediciton: [0]
#
# Question: How to get a list of current open windows/process with Java?,<p>Does any one know how do I get the current open windows or process of a local machine using Java?  </p>
#
# <p>What I'm trying to do is: list the current open task, windows or process open, like in  Windows Taskmanager, but using a multi-platform approach - using only Java if it's possible.</p>
#
#  Prediciton: [0]
#
# Question: How can I detect when an Exception's been thrown globally in Java?,<p>How can I detect when an Exception has been thrown anywhere in my application?</p>
#
# <p>I'm try to auto-magically send myself an email whenever an exception is thrown anywhere in my Java Desktop Application.  I figure this way I can be more proactive.</p>
#
# <p>I know I could just explicitly log and notify myself whenever an exception occurs, but I'd have to do it everywhere and I might(more likely will) miss a couple.</p>
#
# <p>Any suggestions?</p>
#
#  Prediciton: [0]
#
# Question: How do you ensure multiple threads can safely access a class field?,<p>When a class field is accessed via a getter method by multiple threads, how do you maintain thread safety? Is the synchronized keyword sufficient?</p>
#
# <p>Is this safe:</p>
#
# <pre><code>public class SomeClass {
#     private int val;
#
#     public synchronized int getVal() {
#         return val;
#     }
#
#     private void setVal(int val) {
#         this.val = val;
#     }
# }
# </code></pre>
#
# <p>or does the setter introduce further complications?</p>
#
#  Prediciton: [1]
#
# Question: How can I refactor HTML markup out of my property files?,<p>I've recently inherited a internationalized and text-heavy Struts 1.1 web application. Many of the JSP files look like:</p>
#
# <pre class="lang-jsp prettyprint-override"><code>&lt;p&gt;
#     &lt;bean:message key="alert" /&gt;
# &lt;/p&gt;
# </code></pre>
#
# <p>and the properties files look like:</p>
#
# <pre><code>messages.properties
# alert=Please update your &lt;a href="/address.do"&gt;address&lt;/a&gt; and &lt;a href="/contact.do"&gt;contact information&lt;/a&gt;.
# </code></pre>
#
# <p>with the appropriate translations in N other languages (messages_fr.properties, etc).</p>
#
# <p>Problems:</p>
#
# <ol>
# <li><em><strong>DRY violation</strong></em> - I have N references to my Struts action URLs instead of 1, which makes refactoring action URLs error-prone.</li>
# <li><em><strong>Mixed concerns</strong></em> - My application's markup is now in more than just my JSP files, making it difficult for a web specialist to tweak the markup (using CSS, etc).</li>
# <li><em><strong>Post-translation markup</strong></em> - Anytime I receive newly-translated text, I must decide what to surround with the <code>&lt;a&gt;...&lt;/a&gt;</code> markup. Easy for English but less so for unfamiliar languages.</li>
# </ol>
#
# <p>I've considered adding placeholders in the messages file, like:</p>
#
# <pre><code>alert=Please update your {0} and {1}.
# </code></pre>
#
# <p>but then the words "address" and "contact information" would somehow need to be localized, wrapped with markup, and passed to my message tag - and I can't see an easy way to do it.</p>
#
# <p>What can I do to improve this?</p>
#
#  Prediciton: [0]
#
# Question: How do you authenticate against an Active Directory server using Spring Security?,<p>I'm writing a Spring web application that requires users to login.  My company has an Active Directory server that I'd like to make use of for this purpose.  However, I'm having trouble using Spring Security to connect to the server.</p>
#
# <p>I'm using Spring 2.5.5 and Spring Security 2.0.3, along with Java 1.6.</p>
#
# <p>If I change the LDAP URL to the wrong IP address, it doesn't throw an exception or anything, so I'm wondering if it's even <em>trying</em> to connect to the server to begin with.</p>
#
# <p>Although the web application starts up just fine, any information I enter into the login page is rejected.  I had previously used an InMemoryDaoImpl, which worked fine, so the rest of my application seems to be configured correctly.</p>
#
# <p>Here are my security-related beans:</p>
#
# <pre><code>  &lt;beans:bean id="ldapAuthProvider" class="org.springframework.security.providers.ldap.LdapAuthenticationProvider"&gt;
#     &lt;beans:constructor-arg&gt;
#       &lt;beans:bean class="org.springframework.security.providers.ldap.authenticator.BindAuthenticator"&gt;
#         &lt;beans:constructor-arg ref="initialDirContextFactory" /&gt;
#         &lt;beans:property name="userDnPatterns"&gt;
#           &lt;beans:list&gt;
#             &lt;beans:value&gt;CN={0},OU=SBSUsers,OU=Users,OU=MyBusiness,DC=Acme,DC=com&lt;/beans:value&gt;
#           &lt;/beans:list&gt;
#         &lt;/beans:property&gt;
#       &lt;/beans:bean&gt;
#     &lt;/beans:constructor-arg&gt;
#   &lt;/beans:bean&gt;
#
#   &lt;beans:bean id="userDetailsService" class="org.springframework.security.userdetails.ldap.LdapUserDetailsManager"&gt;
#     &lt;beans:constructor-arg ref="initialDirContextFactory" /&gt;
#   &lt;/beans:bean&gt;
#
#   &lt;beans:bean id="initialDirContextFactory" class="org.springframework.security.ldap.DefaultInitialDirContextFactory"&gt;
#     &lt;beans:constructor-arg value="ldap://192.168.123.456:389/DC=Acme,DC=com" /&gt;
#   &lt;/beans:bean&gt;
# </code></pre>
#
#  Prediciton: [0]
#
# Question: How do I set an Application's Icon Globally in Swing?,<p>I know I can specify one for each form, or for the root form and then it'll cascade through to all of the children forms, but I'd like to have a way of overriding the default Java Coffee Cup for all forms even those I might forget.</p>
#
# <p>Any suggestions?</p>
#
#  Prediciton: [0]
#
# Question: How do I force a Java subclass to define an Annotation?,<p>If a class defined an annotation, is it somehow possible to force its subclass to define the same annotation?</p>
#
# <p>For instance, we have a simple class/subclass pair that share the <code>@Author @interface.</code>
# What I'd like to do is force each further subclass to define the same <code>@Author</code> annotation, preventing a <code>RuntimeException</code> somewhere down the road. </p>
#
# <p>TestClass.java:</p>
#
# <pre><code>import java.lang.annotation.*;
#
# @Retention(RetentionPolicy.RUNTIME)
# @interface Author { String name(); }
#
# @Author( name = "foo" )
# public abstract class TestClass
# {
#     public static String getInfo( Class&lt;? extends TestClass&gt; c )
#     {
#         return c.getAnnotation( Author.class ).name();
#     }
#
#     public static void main( String[] args )
#     {
#         System.out.println( "The test class was written by "
#                         + getInfo( TestClass.class ) );
#         System.out.println( "The test subclass was written by "
#                         + getInfo( TestSubClass.class ) );
#     }
# }
# </code></pre>
#
# <p>TestSubClass.java:</p>
#
# <pre><code>@Author( name = "bar" )
# public abstract class TestSubClass extends TestClass {}
# </code></pre>
#
# <p>I know I can enumerate all annotations at runtime and check for the missing <code>@Author</code>, but I'd really like to do this at compile time, if possible.</p>
#
#  Prediciton: [1]
#
# Question: How can I show a "temporarily out of service" page to web-app users during maintenance?,<p>I develop and maintain small intranet web apps written in JSP and Java.
# They run on a Resin web server, without dedicated httpd like Apache.</p>
#
# <p>Before performing maintenance, I activate a very simple Ajax message to urge users to logout.</p>
#
# <p>What I want is, while I do maintenance, a user trying to log in to that particular app
# to see a "Sorry, temporarily out of service" page, while all other web apps running on the same web server are available as usual.</p>
#
# <p>What are some best practices in this situation?</p>
#
#  Prediciton: [0]
#
# Question: How can I share a variable or object between two or more Servlets?,<p>I would like to know if there is some way to share a variable or an object between two or more Servlets, I mean some "standard" way. I suppose that this is not a good practice but is a easier way to build a prototype.</p>
#
# <p>I don't know if it depends on the technologies used, but I'll use Tomcat 5.5</p>
#
# <hr>
#
# <p>I want to share a Vector of objects of a simple class (just public attributes, strings, ints, etc). My intention is to have a static data like in a DB, obviously it will be lost when the Tomcat is stopped. (it's just for Testing)</p>
#
#  Prediciton: [1]
#
# Question: How can I lock a file using java (if possible),<p>I have a Java process that opens a file using a FileReader. How can I prevent another (Java) process from opening this file, or at least notify that second process that the file is already opened? Does this automatically make the second process get an exception if the file is open (which solves my problem) or do I have to explicitly open it in the first process with some sort of flag or argument?</p>
#
# <h3>To clarify:</h3>
#
# <p>I have a Java app that lists a folder and opens each file in the listing for processing it. It processes each file after the other. The processing of each file consists of reading it and doing some calculations based on the contents and it takes about 2 minutes. I also have another Java app that does the same thing but instead writes on the file. What I want is to be able to run these apps at the same time so the scenario goes like this. ReadApp lists the folder and finds files A, B, C. It opens file A and starts the reading. WriteApp lists the folder and finds files A, B, C. It opens file A, sees that is is open (by an exception or whatever way) and goes to file B. ReadApp finishes file A and continues to B. It sees that it is open and continues to C. It is crucial that WriteApp doesn't write while ReadApp is reading the same file or vice versa. They are different processes.</p>
#
#  Prediciton: [1]
#
# Question: What to do with null fields in compare()?,<p>In Java, I use a class in which some fields can be <code>null</code>. For example:</p>
#
# <pre><code>class Foo {
#     String bar;
#     //....
# }
# </code></pre>
#
# <p>I want to write a BarComparator for this class,</p>
#
# <pre><code>    private static class BarComparator
#             implements Comparator&lt;Foo&gt; {
#         public int compare( final Foo o1, final Foo o2 )
#         {
#             // Implementation goes here
#         }
#     }
# </code></pre>
#
# <p>Is there a standard way to deal with the fact that any of <code>o1</code>, <code>o2</code>, <code>o1.bar</code>, <code>o2.bar</code> can be <code>null</code>, without writing lots of nested <code>if</code>...<code>else</code>?</p>
#
# <p>Cheers!</p>
#
#  Prediciton: [1]
#
# Question: How do I make a list with checkboxes in Java Swing?,<p>What would be the best way to have a list of items with a checkbox each in Java Swing?</p>
#
# <p>I.e. a JList with items that have some text and a checkbox each?</p>
#
#  Prediciton: [0]
#
# Question: How to test java application for performance bottlenecks?,<p>I am reviewing a big java application to see if there are any performance bottlenecks. The real problem is that I cannot pinpoint the performance issues to any single module. The whole application is slow as such.</p>
#
# <p>Is there some tool/technique I can use to help me out in this?</p>
#
#  Prediciton: [0]
#
# Question: How to avoid type safety warnings with Hibernate HQL results?,<p>For example I have such query:</p>
#
# <pre><code>Query q = sess.createQuery("from Cat cat");
# List cats = q.list();
# </code></pre>
#
# <p>If I try to make something like this it will show warning "Type safety: The expression of type List needs unchecked conversion to conform to List":</p>
#
# <pre><code>List&lt;Cat&gt; cats = q.list();
# </code></pre>
#
# <p>Is there a way to avoid it?</p>
#
#  Prediciton: [1]
#
# Question: How do you embed binary data in XML?,<p>I have two applications written in Java that communicate with each other using XML messages over the network.  I'm using a SAX parser at the receiving end to get the data back out of the messages.  One of the requirements is to embed binary data in an XML message, but SAX doesn't like this.  Does anyone know how to do this?</p>
#
# <p>UPDATE:  I got this working with the <a href="http://commons.apache.org/codec/apidocs/org/apache/commons/codec/binary/Base64.html" rel="noreferrer">Base64</a> class from the <a href="http://commons.apache.org/codec/" rel="noreferrer">apache commons codec library</a>, in case anyone else is trying something similar.</p>
#
#  Prediciton: [0]
#
# Question: How can I detect if caps lock is toggled in Swing?,<p>I'm trying to build a better username/password field for my workplace and would like to be able to complain when they have their caps lock on.</p>
#
# <p>Is this possible?  And if so I'd like to have it detected before the client types their first letter.</p>
#
# <p>Is there a non-platform specific way to do this?</p>
#
#  Prediciton: [1]
#
# Question: Why aren't variables declared in "try" in scope in "catch" or "finally"?,<p>In C# and in Java (and possibly other languages as well), variables declared in a "try" block are not in scope in the corresponding "catch" or "finally" blocks.  For example, the following code does not compile:</p>
#
# <pre><code>try {
#   String s = "test";
#   // (more code...)
# }
# catch {
#   Console.Out.WriteLine(s);  //Java fans: think "System.out.println" here instead
# }
# </code></pre>
#
# <p>In this code, a compile-time error occurs on the reference to s in the catch block, because s is only in scope in the try block.  (In Java, the compile error is "s cannot be resolved"; in C#, it's "The name 's' does not exist in the current context".)</p>
#
# <p>The general solution to this issue seems to be to instead declare variables just before the try block, instead of within the try block:</p>
#
# <pre><code>String s;
# try {
#   s = "test";
#   // (more code...)
# }
# catch {
#   Console.Out.WriteLine(s);  //Java fans: think "System.out.println" here instead
# }
# </code></pre>
#
# <p>However, at least to me, (1) this feels like a clunky solution, and (2) it results in the variables having a larger scope than the programmer intended (the entire remainder of the method, instead of only in the context of the try-catch-finally).</p>
#
# <p>My question is, what were/are the rationale(s) behind this language design decision (in Java, in C#, and/or in any other applicable languages)?  </p>
#
#  Prediciton: [1]
#
# Question: How do I truncate a java string to fit in a given number of bytes, once UTF-8 encoded?,<p>How do I truncate a java <code>String</code> so that I know it will fit in a given number of bytes storage once it is UTF-8 encoded?</p>
#
#  Prediciton: [1]
#
# Question: How do you remotely update Java applications?,<p>We've got a Java server application that runs on a number of computers, all connected to the Internet, some behind firewalls. We need to remotely update the JAR files and startup scripts from a central site, with no noticeable interruption to the app itself.</p>
#
# <p>The process has to be unattended and foolproof (i.e. we can't afford to break the app due to untimely internet outages).</p>
#
# <p>In the past we've used a variety of external scripts and utilities to handle similar tasks, but because they have their own dependencies, the result is harder to maintain and less portable. Before making something new, I want to get some input from the community.</p>
#
# <p>Has anyone found a good solution for this already? Got any ideas or suggestions?</p>
#
# <p><em>Just to clarify: This app is a server, but not for web applications (no webapp containers or WAR files here). It's just an autonomous Java program.</em></p>
#
#  Prediciton: [0]

# %% [markdown]
# ## b) - Filter the entire dataset

# %%
#create the target column
df['OK'] = None

#iterates over the dataframe
for index, row in df.iterrows():
    
    #extract the correct data to feed model
    data = df.loc[index, 'title_tag_chunk']
    #predicts whether or not it is ok
    prediction = trained_NB_model.predict([data])
    #saves prediction to row
    df.loc[index, 'OK'] = prediction

# %%
df.OK.count()
# Out:
# 10728

# %%
df
# Out:
#              Id                                              Title  \
# 0          5328  Why can't I use a try block around my super() ...
# 1         15690         How do you begin designing a large system?
# 2         24866  Is it essential that I use libraries to manipu...
# 3         25449           How to create a pluginable Java program?
# 4         24991  Why can't I explicitly pass the type argument ...
# 5         32041  How to remove debug statements from production...
# 6         32529     How do I restrict JFileChooser to a directory?
# 7         33262  How do I load an org.w3c.dom.Document from XML...
# 8         35186                  How do I fix a NoSuchMethodError?
# 9         37089  How can an application use multiple cores or C...
# 10        37335  How to deal with "java.lang.OutOfMemoryError: ...
# 11        41107     How to generate a random alpha-numeric string?
# 12        46663  How can I send an email by Java application us...
# 13        49379  How to lock compiled Java classes to prevent d...
# 14        64036  How do you make a deep copy of an object in Java?
# 15        71585             How to get parametrized Class instance
# 16        71625  Why would a static nested interface be used in...
# 17        81567     How do you handle different Java IDEs and svn?
# 18        86780  How to check if a String contains another Stri...
# 19        94011  How to abort a thread in a fast and clean way ...
# 20       107823  Why is my Java program leaking memory when I c...
# 21       112503     How do I remove objects from an array in Java?
# 22       132478               How to perform string Diffs in Java?
# 23       136308  How do you refresh maven dependencies from ecl...
# 24       136580  How to have a Label inherite a Composite's GC ...
# 25       150167  How do I list / export private keys from a key...
# 26       150849           How to get JRE/JDK with matching source?
# 27       158665  How do I delete a dirset of directories with Ant?
# 28       169799  How do I dynamically add Panels to other panel...
# 29       171828  How best to store Subversion version informati...
# ...         ...                                                ...
# 10698  43523276  Why does this method reference assignment comp...
# 10699  43574426  How to resolve java.lang.NoClassDefFoundError:...
# 10700  43860618  Why is an ArrayList of ArrayLists not multidim...
# 10701  43893586  How to instantiate a generic recursive class i...
# 10702  43415131  How to suitably compose Predicate and Function...
# 10703  43993329  Why does the same JAR file have different hash...
# 10704  44068424           How to pass a getter as lambda function?
# 10705  44219903                      Why is shared mutability bad?
# 10706  44420937  How do you properly synchronize threads on the...
# 10707  44661078        Why does java stream.count() return a long?
# 10708  44647449   How do I use j2html without rendering everything
# 10709  45438784  How to create a method to return 1 or 0 withou...
# 10710  45685026           How can I get a random number in Kotlin?
# 10711  45018175  How could we make use of ClusterListener in Mo...
# 10712  45675002  How to see org.codehaus.jackson log messages -...
# 10713  45814389  How to write the clear() method in the list da...
# 10714  45817256  How to avoid "The job exceeded the maximum tim...
# 10715  30164134                How to use properties-maven-plugin?
# 10716  46075776  How to match stream elements but return false ...
# 10717  39173137       Why does the JVM use giant int[] of all 0's?
# 10718  45888068  How do I run tests compiling a kotlin file in ...
# 10719  46438557         How to extract the file jre-9/lib/modules?
# 10720  46756421          How to pass arguments to a jshell script?
# 10721  47102658  How to generate random values where a percenta...
# 10722  47196129  How to launch a Java program with precisely co...
# 10723  48013227  How to sum the values in List<int[]> using Java 8
# 10724  48033944  How are coroutines implemented in JVM langs wi...
# 10725  48273090  How to apply Filtering on groupBy in java streams
# 10726  48446622  How to use Java 8 Optionals, performing an act...
# 10727  48835996  How to join two Optional<String> with a delimi...
#
#                                                     Body  \
# 0      <p>So, in Java, the first line of your constru...
# 1      <p>It's been mentioned to me that I'll be the ...
# 2      <p>I am using Java back end for creating an XM...
# 3      <p>I want to create a Java program that can be...
# 4      <p>I have defined a Java function:</p>\n\n<pre...
# 5      <p>Is it possible for the compiler to remove s...
# 6      <p>I want to limit my users to a directory and...
# 7      <p>I have a complete XML document in a string ...
# 8      <p>I'm getting a <code>NoSuchMethodError</code...
# 9      <p>When launching a thread or a process in .NE...
# 10     <p>I am writing a client-side <strong>Swing</s...
# 11     <p>I've been looking for a <em>simple</em> Jav...
# 12     <p>Is it possible to send an email from my Jav...
# 13     <p>How do I lock compiled Java classes to prev...
# 14     <p>In java it's a bit difficult to implement a...
# 15     <p>Since generics were introduced, Class is pa...
# 16     <p>I have just found a static nested interface...
# 17     <p>How do you ensure, that you can checkout th...
# 18     <p>Say I have two strings,</p>\n\n<pre><code>S...
# 19     <p>Here is my problem: I've got a dialog with ...
# 20     <p>(Jeopardy-style question, I wish the answer...
# 21     <p>Given an array of <strong>n</strong> Object...
# 22     <p>I would need to perform Diffs between Java ...
# 23     <p>We recently started using maven for depende...
# 24     <p>I'm writing an app and our designers want t...
# 25     <p>How do I list and export a private key from...
# 26     <p>I'd like to get at least one JRE/JDK level ...
# 27     <p>I want to delete all directories and subdir...
# 28     <p>I'm trying to get into java again (it's bee...
# 29     <p>When receiving a bug report or an it-doesnt...
# ...                                                  ...
# 10698  <p>I'm struggling to see why the following cod...
# 10699  <p>I have some code that uses JAXB API classes...
# 10700  <p>I recently appeared for an interview in whi...
# 10701  <p>My problem is that I am using a class not d...
# 10702  <p>The purpose is to create a new Predicate us...
# 10703  <p>I've been thinking about checking jar file'...
# 10704  <p>I want to pass the getter of a bean as a fu...
# 10705  <p>I was watching a presentation on Java, and ...
# 10706  <p><strong>Question Brief</strong></p>\n\n<p>I...
# 10707  <p>Why doesn't a <a href="https://docs.oracle....
# 10708  <p>I am converting my html rendering code to u...
# 10709  <p>I was asked a question in an interview to r...
# 10710  <p>A generic method that can return a random i...
# 10711  <p>I was trying to look for an example or usag...
# 10712  <p>I am trying to deserialize incoming <em>PUT...
# 10713  <p>I have read some frameworks source code rec...
# 10714  <p>Since approx. 72h I'm getting <code>The job...
# 10715  <p>I'd like to use properties-maven-plugin. I ...
# 10716  <p>I have a stream and would like to check if ...
# 10717  <p>I know there is an intrinsic overhead of th...
# 10718  <p>So far I have </p>\n\n<pre><code>import org...
# 10719  <p>In <code>JRE-9/lib</code> directory (at lea...
# 10720  <h2>Question</h2>\n\n<p>I am willing to pass a...
# 10721  <p>I create a random stream</p>\n\n<pre><code>...
# 10722  <p>As I know JVM before launching a Java appli...
# 10723  <p>I want to find the sum of the <code>List&lt...
# 10724  <p>This question came up after reading the <a ...
# 10725  <p>How do you group first and then apply filte...
# 10726  <p>I have some (simplified) code that uses Jav...
# 10727  <p>I have two <code>Optional</code> strings, <...
#
#                                                     Tags  \
# 0                         exception  mocking  try-catch
# 1                             oop  design  architecture
# 2                                                   xml
# 3                          plugins  plugin-architecture
# 4                                      generics  syntax
# 5                      debugging  compiler-construction
# 6                                   swing  jfilechooser
# 7                                    xml  document  w3c
# 8                                     nosuchmethoderror
# 9                                  c#    multithreading
# 10                 -ee  jvm  out-of-memory  heap-memory
# 11                         string  random  alphanumeric
# 12                      email  gmail  mail  mail-server
# 13                                     jvm  decompiling
# 14                                         class  clone
# 15                                             generics
# 16                                    interface  static
# 17                     eclipse  svn  ide  collaboration
# 18                                               string
# 19                                       multithreading
# 20                         multithreading  memory-leaks
# 21           arrays  data-structures  data-manipulation
# 22                                                 diff
# 23                                     eclipse  maven-2
# 24                                  user-interface  swt
# 25                                        ssl  keystore
# 26
# 27                                           ant  build
# 28                                                swing
# 29                                    svn  ant  release
# ...                                                  ...
# 10698                                                -8
# 10699                                          jaxb  -9
# 10700         arrays  arraylist  multidimensional-array
# 10701                        class  generics  recursion
# 10702     lambda  -8  method-reference  functional-in...
# 10703                              maven  jar  bytecode
# 10704                                        lambda  -8
# 10705                         -8  -stream  immutability
# 10706         c++  multithreading  synchronization  jni
# 10707                                       -8  -stream
# 10708                                      html  j2html
# 10709                      c#  logic  logical-operators
# 10710                               random  jvm  kotlin
# 10711     mongodb  database-replication  mongodb-  mo...
# 10712                  jackson  .util.logging  tcserver
# 10713                                   data-structures
# 10714                    maven  travis-ci  connectivity
# 10715                                             maven
# 10716                                       -8  -stream
# 10717                                     jvm  overhead
# 10718                     android  jvm  kotlin  kotlinc
# 10719                      -9  -module  jdk-tools  jmod
# 10720                                        -9  jshell
# 10721                                        random  -8
# 10722                                    execution-time
# 10723                                            lambda
# 10724                 scala  jvm  kotlin  jvm-languages
# 10725                                   -8  -stream  -9
# 10726                                      -8  optional
# 10727                                      -8  optional
#
#                                                     body  \
# 0      <p>Unfortunately, compilers can't work on theo...
# 1      <p>Do you know much about OOP?  If so, look in...
# 2      <p>It's not essential, but advisable. However,...
# 3      <p>I've done this for software I've written in...
# 4      <p>When the java compiler cannot infer the par...
# 5      <p>Two recommendations.</p>\n\n<p><strong>Firs...
# 6      <p>You can probably do this by setting your ow...
# 7      <p>This works for me in Java 1.5 - I stripped ...
# 8      <p>Without any more information it is difficul...
# 9      <p>If you're using multiple threads, the opera...
# 10     <p>Ultimately you always have a finite max of ...
# 11     <h2>Algorithm</h2>\n\n<p>To generate a random ...
# 12     <p>First download the <a href="https://java.ne...
# 13     <p>Some of the more advanced Java bytecode obf...
# 14     <p>A safe way is to serialize the object, then...
# 15     <p>The Class class is a run-time representatio...
# 16     <p>The static keyword in the above example is ...
# 17     <p>The smart ass answer is "by doing so" - unl...
# 18     <p>Yes, contains is case sensitive.  You can u...
# 19     <p>Try interrupt() as some have said to see if...
# 20     <p>This is a known bug in Java 1.4:\n<a href="...
# 21     <p>[If you want some ready-to-use code, please...
# 22     <p>This library seems to do the trick: <a href...
# 23     <p>Have you tried using the <a href="http://m2...
# 24     <p>Use <strong>composite.setBackgroundMode(SWT...
# 25     <p>A portion of code originally from Example D...
# 26     <p>Most of the useful source will be in the sr...
# 27     <p>Here's the answer that worked for me:</p>\n...
# 28     <p>I figured it out. The comments under the ac...
# 29     <p>Use the <em>svnversion</em> command in your...
# ...                                                  ...
# 10698  <p>The second one</p>\n\n<pre><code>f = Method...
# 10699  <p>The JAXB APIs are considered to be Java EE ...
# 10700  <p>Cay S. Horstmann has stated within his book...
# 10701  <p>You have to declare a class which extends <...
# 10702  <p>I answer my own questions.</p>\n\n<p>Use la...
# 10703  <p>A JAR file is a ZIP file and it contains a ...
# 10704  <p>If the constructor of <code>MyConverter</co...
# 10705  <p>The problem comes into play when performing...
# 10706  <p>If both threads are attached to the JVM, th...
# 10707  <p>Well simply because it's the biggest 64-bit...
# 10708  <pre><code>import static j2html.TagCreator.b;\...
# 10709  <p>If you are given only 0 and 1 then this cou...
# 10710  <p>Generate a random integer between <code>fro...
# 10711  <p><strong>TL;DR</strong></p>\n\n<p>The <code>...
# 10712  <p>For what you say it seems that you're tryin...
# 10713  <p>I guess the motivation is re-using the exis...
# 10714  <p>Enabling caching on Travis CI by adding</p>...
# 10715  <p>Official answer from them is that using rea...
# 10716  <p>You could use</p>\n\n<pre><code>public bool...
# 10717  <p>I've been playing around with this some mor...
# 10718  <p>I found the easiest way to do it is to use ...
# 10719  <p>The <code>modules</code> file is a containe...
# 10720  <p>And what about option <code>-R</code></p>\n...
# 10721  <p>Since the size of the target interval is di...
# 10722  <p>There are a number of sources of uncertaint...
# 10723  <p>You want to flatMap to an IntStream.\nAfter...
# 10724  <p><strong>tl;dr</strong> Summary:</p>\n\n<blo...
# 10725  <p><a href="https://stackoverflow.com/a/482731...
# 10726  <p>I think to stream the three <code>Optional<...
# 10727  <p>One solution is to stream and <code>reduce(...
#
#                                          title_tag_chunk   OK
# 0      Why can't I use a try block around my super() ...  [1]
# 1      How do you begin designing a large system?,<p>...  [0]
# 2      Is it essential that I use libraries to manipu...  [0]
# 3      How to create a pluginable Java program?,<p>I ...  [0]
# 4      Why can't I explicitly pass the type argument ...  [1]
# 5      How to remove debug statements from production...  [0]
# 6      How do I restrict JFileChooser to a directory?...  [0]
# 7      How do I load an org.w3c.dom.Document from XML...  [0]
# 8      How do I fix a NoSuchMethodError?,<p>I'm getti...  [0]
# 9      How can an application use multiple cores or C...  [1]
# 10     How to deal with "java.lang.OutOfMemoryError: ...  [1]
# 11     How to generate a random alpha-numeric string?...  [1]
# 12     How can I send an email by Java application us...  [0]
# 13     How to lock compiled Java classes to prevent d...  [0]
# 14     How do you make a deep copy of an object in Ja...  [1]
# 15     How to get parametrized Class instance,<p>Sinc...  [1]
# 16     Why would a static nested interface be used in...  [1]
# 17     How do you handle different Java IDEs and svn?...  [0]
# 18     How to check if a String contains another Stri...  [1]
# 19     How to abort a thread in a fast and clean way ...  [0]
# 20     Why is my Java program leaking memory when I c...  [1]
# 21     How do I remove objects from an array in Java?...  [1]
# 22     How to perform string Diffs in Java?,<p>I woul...  [1]
# 23     How do you refresh maven dependencies from ecl...  [0]
# 24     How to have a Label inherite a Composite's GC ...  [0]
# 25     How do I list / export private keys from a key...  [1]
# 26     How to get JRE/JDK with matching source?,<p>I'...  [0]
# 27     How do I delete a dirset of directories with A...  [0]
# 28     How do I dynamically add Panels to other panel...  [0]
# 29     How best to store Subversion version informati...  [0]
# ...                                                  ...  ...
# 10698  Why does this method reference assignment comp...  [1]
# 10699  How to resolve java.lang.NoClassDefFoundError:...  [0]
# 10700  Why is an ArrayList of ArrayLists not multidim...  [1]
# 10701  How to instantiate a generic recursive class i...  [1]
# 10702  How to suitably compose Predicate and Function...  [1]
# 10703  Why does the same JAR file have different hash...  [0]
# 10704  How to pass a getter as lambda function?,<p>I ...  [1]
# 10705  Why is shared mutability bad?,<p>I was watchin...  [1]
# 10706  How do you properly synchronize threads on the...  [1]
# 10707  Why does java stream.count() return a long?,<p...  [1]
# 10708  How do I use j2html without rendering everythi...  [1]
# 10709  How to create a method to return 1 or 0 withou...  [0]
# 10710  How can I get a random number in Kotlin?,<p>A ...  [1]
# 10711  How could we make use of ClusterListener in Mo...  [0]
# 10712  How to see org.codehaus.jackson log messages -...  [0]
# 10713  How to write the clear() method in the list da...  [1]
# 10714  How to avoid "The job exceeded the maximum tim...  [0]
# 10715  How to use properties-maven-plugin?,<p>I'd lik...  [0]
# 10716  How to match stream elements but return false ...  [1]
# 10717  Why does the JVM use giant int[] of all 0's?,<...  [1]
# 10718  How do I run tests compiling a kotlin file in ...  [1]
# 10719  How to extract the file jre-9/lib/modules?,<p>...  [0]
# 10720  How to pass arguments to a jshell script?,<h2>...  [0]
# 10721  How to generate random values where a percenta...  [1]
# 10722  How to launch a Java program with precisely co...  [1]
# 10723  How to sum the values in List<int[]> using Jav...  [1]
# 10724  How are coroutines implemented in JVM langs wi...  [1]
# 10725  How to apply Filtering on groupBy in java stre...  [1]
# 10726  How to use Java 8 Optionals, performing an act...  [1]
# 10727  How to join two Optional<String> with a delimi...  [1]
#
# [10728 rows x 7 columns]

# %%
df['OK'] = df['OK'].str.get(0)

# %%
df_ok = df[df.OK == 1]

# %%
df_ok = df_ok.drop(['title_tag_chunk', 'OK'], axis=1)

# %%
df_ok
# Out:
#              Id                                              Title  \
# 0          5328  Why can't I use a try block around my super() ...
# 4         24991  Why can't I explicitly pass the type argument ...
# 9         37089  How can an application use multiple cores or C...
# 10        37335  How to deal with "java.lang.OutOfMemoryError: ...
# 11        41107     How to generate a random alpha-numeric string?
# 14        64036  How do you make a deep copy of an object in Java?
# 15        71585             How to get parametrized Class instance
# 16        71625  Why would a static nested interface be used in...
# 18        86780  How to check if a String contains another Stri...
# 20       107823  Why is my Java program leaking memory when I c...
# 21       112503     How do I remove objects from an array in Java?
# 22       132478               How to perform string Diffs in Java?
# 25       150167  How do I list / export private keys from a key...
# 32        17944    How to round up the result of integer division?
# 34        20778  How do you convert binary data to Strings and ...
# 35       184704  Is it possible to detect if an exception occur...
# 36        26305                      How can I play sound in Java?
# 37        33960    How do you get the ethernet address using Java?
# 39        27240                  Why aren't Enumerations Iterable?
# 40        60160  How to escape text for regular expression in Java
# 41       189787   How to format methods with large parameter lists
# 42        34413   Why am I getting a NoClassDefFoundError in Java?
# 43         7596  How should I structure a Java application, whe...
# 46        40119                     How to find a Java Memory Leak
# 49        20227   How do I use 3DES encryption/decryption in Java?
# 50        62241  How to convert a Reader to InputStream and a W...
# 56         4242  Why doesn't Java autoboxing extend to method i...
# 58        28949  Why do you not explicitly call finalize() or s...
# 59        54909             How do I clone a generic List in Java?
# 61       203475        How do I identify immutable objects in Java
# ...         ...                                                ...
# 10681  37010891  How to map a nested value to a property using ...
# 10682  41049753  How to throttle writes request to cassandra wh...
# 10685  41838323                        Why is BitSet not Iterable?
# 10686  22200676  How to list all properties exposed by a Java c...
# 10687  41854640                 Why does (boolean ^ int > 0) work?
# 10688  41897133                       How do I refactor this loop?
# 10690  42184317     How to avoid a useless return in a Java method
# 10694  43076830  Why does using raw type variables affect signa...
# 10695  43082115  Why is this GoLang solution faster then the eq...
# 10698  43523276  Why does this method reference assignment comp...
# 10700  43860618  Why is an ArrayList of ArrayLists not multidim...
# 10701  43893586  How to instantiate a generic recursive class i...
# 10702  43415131  How to suitably compose Predicate and Function...
# 10704  44068424           How to pass a getter as lambda function?
# 10705  44219903                      Why is shared mutability bad?
# 10706  44420937  How do you properly synchronize threads on the...
# 10707  44661078        Why does java stream.count() return a long?
# 10708  44647449   How do I use j2html without rendering everything
# 10710  45685026           How can I get a random number in Kotlin?
# 10713  45814389  How to write the clear() method in the list da...
# 10716  46075776  How to match stream elements but return false ...
# 10717  39173137       Why does the JVM use giant int[] of all 0's?
# 10718  45888068  How do I run tests compiling a kotlin file in ...
# 10721  47102658  How to generate random values where a percenta...
# 10722  47196129  How to launch a Java program with precisely co...
# 10723  48013227  How to sum the values in List<int[]> using Java 8
# 10724  48033944  How are coroutines implemented in JVM langs wi...
# 10725  48273090  How to apply Filtering on groupBy in java streams
# 10726  48446622  How to use Java 8 Optionals, performing an act...
# 10727  48835996  How to join two Optional<String> with a delimi...
#
#                                                     Body  \
# 0      <p>So, in Java, the first line of your constru...
# 4      <p>I have defined a Java function:</p>\n\n<pre...
# 9      <p>When launching a thread or a process in .NE...
# 10     <p>I am writing a client-side <strong>Swing</s...
# 11     <p>I've been looking for a <em>simple</em> Jav...
# 14     <p>In java it's a bit difficult to implement a...
# 15     <p>Since generics were introduced, Class is pa...
# 16     <p>I have just found a static nested interface...
# 18     <p>Say I have two strings,</p>\n\n<pre><code>S...
# 20     <p>(Jeopardy-style question, I wish the answer...
# 21     <p>Given an array of <strong>n</strong> Object...
# 22     <p>I would need to perform Diffs between Java ...
# 25     <p>How do I list and export a private key from...
# 32     <p>I'm thinking in particular of how to displa...
# 34     <p>I have binary data in a file that I can rea...
# 35     <p>In Java, is there an elegant way to detect ...
# 36     <p>I want to be able to play sound files in my...
# 37     <p>I would like to retrieve the ethernet addre...
# 39     <p>In Java 5 and above you have the foreach lo...
# 40     <p>Does Java have a built-in way to escape arb...
# 41     <p>I have never seen a way to do this nicely, ...
# 42     <p>I am getting a <code>NoClassDefFoundError</...
# 43     <p>First of all, I know how to build a Java ap...
# 46     <p>How do you find a memory leak in Java (usin...
# 49     <p>Every method I write to encode a string in ...
# 50     <p>Is there an easy way to avoid dealing with ...
# 56     <p>I want to convert a primitive to a string, ...
# 58     <p>After reading <a href="https://stackoverflo...
# 59     <p>I have an <code>ArrayList&lt;String&gt;</co...
# 61     <p>In my code, I am creating a collection of o...
# ...                                                  ...
# 10681  <p>Let's say I'm making a call to an API that ...
# 10682  <p>I am using datastax java driver 3.1.0 to co...
# 10685  <p><code>BitSet</code> has a <code>stream()</c...
# 10686  <p>Given a single Java class I'd like to be ab...
# 10687  <p>When you try to do something like this:</p>...
# 10688  <p>I've got an application where I use primiti...
# 10690  <p>I have a situation where the return stateme...
# 10694  <p>Looking into another <a href="https://stack...
# 10695  <p>Recently at work we were playing around wit...
# 10698  <p>I'm struggling to see why the following cod...
# 10700  <p>I recently appeared for an interview in whi...
# 10701  <p>My problem is that I am using a class not d...
# 10702  <p>The purpose is to create a new Predicate us...
# 10704  <p>I want to pass the getter of a bean as a fu...
# 10705  <p>I was watching a presentation on Java, and ...
# 10706  <p><strong>Question Brief</strong></p>\n\n<p>I...
# 10707  <p>Why doesn't a <a href="https://docs.oracle....
# 10708  <p>I am converting my html rendering code to u...
# 10710  <p>A generic method that can return a random i...
# 10713  <p>I have read some frameworks source code rec...
# 10716  <p>I have a stream and would like to check if ...
# 10717  <p>I know there is an intrinsic overhead of th...
# 10718  <p>So far I have </p>\n\n<pre><code>import org...
# 10721  <p>I create a random stream</p>\n\n<pre><code>...
# 10722  <p>As I know JVM before launching a Java appli...
# 10723  <p>I want to find the sum of the <code>List&lt...
# 10724  <p>This question came up after reading the <a ...
# 10725  <p>How do you group first and then apply filte...
# 10726  <p>I have some (simplified) code that uses Jav...
# 10727  <p>I have two <code>Optional</code> strings, <...
#
#                                                     Tags  \
# 0                         exception  mocking  try-catch
# 4                                      generics  syntax
# 9                                  c#    multithreading
# 10                 -ee  jvm  out-of-memory  heap-memory
# 11                         string  random  alphanumeric
# 14                                         class  clone
# 15                                             generics
# 16                                    interface  static
# 18                                               string
# 20                         multithreading  memory-leaks
# 21           arrays  data-structures  data-manipulation
# 22                                                 diff
# 25                                        ssl  keystore
# 32                                           c#    math
# 34                                        serialization
# 35                                   exception-handling
# 36                                                audio
# 37                                 networking  ethernet
# 39                                enumeration  iterable
# 40                                      regex  escaping
# 41                                  formatting  methods
# 42                                 noclassdeffounderror
# 43                                         architecture
# 46                           memory  memory-leaks  jhat
# 49                                     encryption  3des
# 50                                               stream
# 56                                           autoboxing
# 58                                   garbage-collection
# 59                                      generics  clone
# 61                 functional-programming  immutability
# ...                                                  ...
# 10681                                     json  jackson
# 10682     multithreading  datastax--driver  rate-limi...
# 10685                                  iterable  bitset
# 10686     eclipse  reflection  recursion  eclipse-plu...
# 10687                                            syntax
# 10688                                       refactoring
# 10690
# 10694                   generics  type-erasure  erasure
# 10695                                   performance  go
# 10698                                                -8
# 10700         arrays  arraylist  multidimensional-array
# 10701                        class  generics  recursion
# 10702     lambda  -8  method-reference  functional-in...
# 10704                                        lambda  -8
# 10705                         -8  -stream  immutability
# 10706         c++  multithreading  synchronization  jni
# 10707                                       -8  -stream
# 10708                                      html  j2html
# 10710                               random  jvm  kotlin
# 10713                                   data-structures
# 10716                                       -8  -stream
# 10717                                     jvm  overhead
# 10718                     android  jvm  kotlin  kotlinc
# 10721                                        random  -8
# 10722                                    execution-time
# 10723                                            lambda
# 10724                 scala  jvm  kotlin  jvm-languages
# 10725                                   -8  -stream  -9
# 10726                                      -8  optional
# 10727                                      -8  optional
#
#                                                     body
# 0      <p>Unfortunately, compilers can't work on theo...
# 4      <p>When the java compiler cannot infer the par...
# 9      <p>If you're using multiple threads, the opera...
# 10     <p>Ultimately you always have a finite max of ...
# 11     <h2>Algorithm</h2>\n\n<p>To generate a random ...
# 14     <p>A safe way is to serialize the object, then...
# 15     <p>The Class class is a run-time representatio...
# 16     <p>The static keyword in the above example is ...
# 18     <p>Yes, contains is case sensitive.  You can u...
# 20     <p>This is a known bug in Java 1.4:\n<a href="...
# 21     <p>[If you want some ready-to-use code, please...
# 22     <p>This library seems to do the trick: <a href...
# 25     <p>A portion of code originally from Example D...
# 32     <p>Found an elegant solution:</p>\n\n<pre><cod...
# 34     <p>If you encode it in base64, this will turn ...
# 35     <p>Your idea about setting a variable outside ...
# 36     <p>I wrote the following code that works fine....
# 37     <p><a href="http://java.sun.com/javase/6/docs/...
# 39     <p>Enumeration hasn't been modified to support...
# 40     <p>Since <a href="http://download.oracle.com/j...
# 41     <p>A large set of parameters like this is ofte...
# 42     <p>This is caused when there is a class file t...
# 43     <p>I've really come to like Maven's <a href="h...
# 46     <p>I use following approach to finding memory ...
# 49     <p>Your code was fine except for the Base 64 e...
# 50     <p>You can't really avoid dealing with the tex...
# 56     <p>Java autoboxing/unboxing doesn't go to the ...
# 58     <p>The short answer: Java garbage collection i...
# 59     <pre><code>ArrayList newArrayList = (ArrayList...
# 61     <p>There is no reliable way to detect if a cla...
# ...                                                  ...
# 10681  <p>You can achieve this like that:</p>\n\n<pre...
# 10682  <p>Not an authoritative answer but maybe it wo...
# 10685  <p>None of the methods in <code>Iterable</code...
# 10686  <p>Have just found a useful way of achieving s...
# 10687  <p>It's simple: <code>&gt;</code> has higher <...
# 10688  <p>You <s>can't</s> shouldn't (*) do this in a...
# 10690  <p>The compiler's heuristics will never let yo...
# 10694  <p>The JLS bit that says this (a bit unclearly...
# 10695  <p>As it turns out, your programs aren't as eq...
# 10698  <p>The second one</p>\n\n<pre><code>f = Method...
# 10700  <p>Cay S. Horstmann has stated within his book...
# 10701  <p>You have to declare a class which extends <...
# 10702  <p>I answer my own questions.</p>\n\n<p>Use la...
# 10704  <p>If the constructor of <code>MyConverter</co...
# 10705  <p>The problem comes into play when performing...
# 10706  <p>If both threads are attached to the JVM, th...
# 10707  <p>Well simply because it's the biggest 64-bit...
# 10708  <pre><code>import static j2html.TagCreator.b;\...
# 10710  <p>Generate a random integer between <code>fro...
# 10713  <p>I guess the motivation is re-using the exis...
# 10716  <p>You could use</p>\n\n<pre><code>public bool...
# 10717  <p>I've been playing around with this some mor...
# 10718  <p>I found the easiest way to do it is to use ...
# 10721  <p>Since the size of the target interval is di...
# 10722  <p>There are a number of sources of uncertaint...
# 10723  <p>You want to flatMap to an IntStream.\nAfter...
# 10724  <p><strong>tl;dr</strong> Summary:</p>\n\n<blo...
# 10725  <p><a href="https://stackoverflow.com/a/482731...
# 10726  <p>I think to stream the three <code>Optional<...
# 10727  <p>One solution is to stream and <code>reduce(...
#
# [5118 rows x 5 columns]

# %%
df_ok.to_csv('./data/filtered_data_ready_for_app.csv')

# %%
for item in list(df_ok.Title):
    print(item)
# Out:
# Why can't I use a try block around my super() call?
# Why can't I explicitly pass the type argument to a generic Java method?
# How can an application use multiple cores or CPUs in .NET or Java?
# How to deal with "java.lang.OutOfMemoryError: Java heap space" error (64MB heap size)
# How to generate a random alpha-numeric string?
# How do you make a deep copy of an object in Java?
# How to get parametrized Class instance
# Why would a static nested interface be used in Java?
# How to check if a String contains another String in a case insensitive manner in Java?
# Why is my Java program leaking memory when I call run() on a Thread object?
# How do I remove objects from an array in Java?
# How to perform string Diffs in Java?
# How do I list / export private keys from a keystore?
# How to round up the result of integer division?
# How do you convert binary data to Strings and back in Java?
# Is it possible to detect if an exception occurred before I entered a finally block?
# How can I play sound in Java?
# How do you get the ethernet address using Java?
# Why aren't Enumerations Iterable?
# How to escape text for regular expression in Java
# How to format methods with large parameter lists
# Why am I getting a NoClassDefFoundError in Java?
# How should I structure a Java application, where do I put my classes?
# How to find a Java Memory Leak
# How do I use 3DES encryption/decryption in Java?
# How to convert a Reader to InputStream and a Writer to OutputStream?
# Why doesn't Java autoboxing extend to method invocations of methods of the autoboxed types?
# Why do you not explicitly call finalize() or start the garbage collector?
# How do I clone a generic List in Java?
# How do I identify immutable objects in Java
# How to control the capitalization of month and day names returned by DateFormat?
# How do I format a number in Java?
# How to instantiate a Java array given an array type at runtime?
# Why doesn't Java offer operator overloading?
# How can I set a timeout against a BufferedReader based upon a URLConnection in Java?
# How can I determine the IP of my router/gateway in Java?
# Is it safe to generally assume that toString() has a low cost?
# How to determine whether a character is a letter in Java?
# How can a Java program get its own process ID?
# How do you ensure multiple threads can safely access a class field?
# How do I force a Java subclass to define an Annotation?
# How can I share a variable or object between two or more Servlets?
# How can I lock a file using java (if possible)
# What to do with null fields in compare()?
# How to avoid type safety warnings with Hibernate HQL results?
# How can I detect if caps lock is toggled in Swing?
# Why aren't variables declared in "try" in scope in "catch" or "finally"?
# How do I truncate a java string to fit in a given number of bytes, once UTF-8 encoded?
# Why pool Stateless session beans?
# How do I add a separator to a JComboBox in Java?
# How to convert a date String to a Date or Calendar object?
# How to program a full-screen mode in Java?
# Why does byteArray have a length of 22 instead of 20?
# Why do I get an OutOfMemoryError when inserting 50,000 objects into HashMap?
# How much resources do sleeping and waiting threads consume
# How to efficiently iterate over each entry in a 'Map'?
# How to write java.util.Properties to XML with sorted keys?
# How can I discover resources in a Java jar with a wildcard name?
# How to format a duration in java? (e.g format H:MM:SS)
# Is it OK to have an 'empty' class that extends another class?
# How much memory do Enums take?
# How do I find out what type each object is in a ArrayList<Object>?
# Why does Java not have block-scoped variable declarations?
# Why do we need the decorator in the decorator design pattern?
# Why should the interface for a Java class be preferred?
# How to convert Strings to and from UTF8 byte arrays in Java
# Why Java and Python garbage collection methods are different?
# Why can't I declare static methods in an interface?
# How do you specify a port range for Java sockets?
# How do I peek at the first two bytes in an InputStream?
# Why would you ever implement finalize()?
# How to emulate C# as-operator in Java
# How can I catch AWT thread exceptions in Java?
# How to multiply 10 to an "Integer" object in Java?
# Why aren't Java Collections remove methods generic?
# How to detect synchronization violations with Java
# How to write an RSS feed with Java?
# How do I invoke a Java method when given the method name as a string?
# How do you force constructor signatures and static methods?
# How can I figure out what is holding on to unfreed objects?
# How can I get the current date and time in UTC or GMT in Java?
# How to implement simple threading with a fixed number of worker threads
# Why does "abcd".StartsWith("") return true?
# How can I see what is in my heap in Java?
# How can elements be added to a wildcard generic collection?
# How to resolve a Java Rounding Double issue
# Why does HttpServlet implement Serializable?
# How should I load Jars dynamically at runtime?
# How to determine the class of a generic type?
# Why is "null" present in C# and Java?
# Is it possible with Java to delete to the Recycle Bin?
# How many threads should I use in my Java program?
# How to stop Hibernate from eagerly fetching many-to-one associated object
# How to serialize an object into a string
# How to scan a folder in Java?
# How to unit test abstract classes: extend with stubs?
# How to find and kill running Win-Processes from within Java?
# How to get date picture created in java
# How does the Java 'for each' loop work?
# How can I access a public static member of a Java class from ColdFusion?
# How do I find my PID in Java or JRuby on Linux?
# How do you compare two version Strings in Java?
# Why can't I switch on a String?
# How do I get whole and fractional parts from double in JSP/Java?
# How to do Gesture Recognition using Accelerometers
# How does Java's serialization work and when it should be used instead of some other persistence technique?
# How to sanity check a date in Java
# How do I add a type to GWT's Serialization Policy whitelist?
# How to round a number to n decimal places in Java
# Why can final constants in Java be overridden?
# How do I use Java to read from a file that is actively being written to?
# How to detect when an object is no longer referenced
# How to compare objects by multiple fields
# How can I cause a child process to exit when the parent does?
# How to specify firstDayOfWeek for java.util.Calendar using a JVM argument
# Is it good practice to use the xor operator for boolean checks?
# How good is FreeBSD as a development platform?
# How to split a huge zip file into multiple volumes?
# Why can't strings be mutable in Java and .NET?
# Why is Java's Cloneable Interface Not Generic?
# How does the Sun JVM map Java threads to Windows threads?
# How to trace a NullPointerException in a chain of getters
# Why are Exceptions not Checked in .NET?
# How to convert string result of enum with overridden toString() back to enum?
# How do I time a method's execution in Java?
# Why does notifyAll() raise IllegalMonitorStateException when synchronized on Integer?
# Why Java needs Serializable interface?
# Why does this regular expression kill the Java regex engine?
# How to use Java reflection when the enum type is a Class?
# Why is the Java main method static?
# Is it possible to add to the available parameters of a request (HttpServletRequest)
# Why does Java's hashCode() in String use 31 as a multiplier?
# How do I get rid of Java child processes when my Java app exits/crashes?
# How do I set environment variables from Java?
# How should I cast for Java generic with multiple bounds?
# Why is Class.newInstance() "evil"?
# How to access java-classes in the default-package?
# Why can't I use a type argument in a type parameter with multiple bounds?
# How do I make the method return type generic?
# How to use Class<T> in Java?
# How can I handle multiple mouse inputs in Java?
# How to use enums with JPA
# How to automatically generate N "distinct" colors?
# How can I see if an element in an int array is empty?
# How can "while (i == i) ;" be a non-infinite loop in a single threaded application?
# How to avoid, that URL.equals needs access to the internet in Java?
# Why is this code with several "or" statements slightly faster than using a lookup table in Java?
# How slow are Java exceptions?
# How do you define a class of constants in Java?
# How to refer to the outer class in another instance of a non-static inner class?
# How to store a java.util.Date into a MySQL timestamp field in the UTC/GMT timezone?
# How do I extract a tar file in Java?
# Why are there no byte or short literals in Java?
# Why is Java able to store 0xff000000 as an int?
# How do I move from Java to C#?
# Why was constness removed from Java and C#?
# How can I generically tell if a Java Class is a primitive type?
# How to subtract X days from a date using Java calendar?
# How to increment a java String through all the possibilities?
# How can I display a byte array as a String in java's debug detail formatter?
# How can I initialise a static Map?
# How can I check if a method is static using reflection?
# How to bring a window to the front?
# How to test whether method return type matches List<String>
# How to show if a method may return null
# How to handle escape sequences in string literals in ANTLR 3?
# How do I split a string with any whitespace chars as delimiters?
# How to handle calendar TimeZones using Java?
# How do you determine the ideal buffer size when using FileInputStream?
# How do I set Java's min and max heap size through environment variables?
# How are Java Thread priorities translated to an OS thread priority?
# How to remove System.out.println's from codebase
# How to suppress Java compiler warnings for specific functions
# How do I call one constructor from another in Java?
# How to backup ArrayList in Java?
# How to convert UTF-8 to US-Ascii in Java
# How can I implement the Iterable interface?
# How can I pad a String in Java?
# Why is my simple comparator broken?
# How can I get the length of a JTextField's contents as the user types?
# How to calculate java BufferedImage filesize
# How does Java Garbage collector handle self-reference?
# How to reschedule a task using a ScheduledExecutorService?
# Why is January month 0 in Java Calendar?
# How to ensure hashCode() is consistent with equals()?
# How can I generate an MD5 hash?
# How do I test the availability of the internet in Java?
# How are java.lang.Object's protected methods protected from subclasses?
# How Can I Avoid Using Exceptions for Flow Control?
# How do you handle Socket Disconnecting in Java?
# Why does my application still run after closing main window?
# How to create a deep unmodifiable collection?
# Is it possible to monkey patch in Java?
# How do I convert between ISO-8859-1 and UTF-8 in Java?
# How does a Java compiler parse typecasts?
# How do I write (test) code that will not be optimized by the compiler/JIT?
# Why doesn't Java support unsigned ints?
# How to call java objects and functions from CPython?
# How do you kill a thread in Java?
# How do I discover the Quarter of a given Date?
# How do you get the "object reference" of an object in java when toString() and hashCode() have been overridden?
# How much null checking is enough?
# Why is Long.valueOf(0).equals(Integer.valueOf(0)) false?
# How do I append a newline character for all lines except the last one?
# How to replace a plus character using Java's String.replaceAll method
# How to cause soft references to be cleared in Java?
# Why can't enum's constructor access static fields?
# How to check if a variable exists in a FreeMarker template?
# How do you make REALLY large boolean arrays using Java?
# How do I see if a substring exists inside another string in Java 1.4?
# Why are interfaces preferred to abstract classes?
# Why is using a class as a struct bad practice in Java?
# How are Anonymous (inner) classes used in Java?
# How can I make this java generic cast?
# How to organize packages (and prevent dependency cycles)?
# How do I use a foreach loop in Java to loop through the values in a HashMap?
# How can I find all classes on the classpath that have a specific method annotation?
# How good is java.util.Random?
# How can I count the time it takes a function to complete in Java?
# How to invoke groovy with 'java' from command line
# Why null cast?
# Why was "new Date(int year, int month, int day)" deprecated?
# How do I pass a variable from one Thread Group to another in JMeter
# Why wasn't the Java "throws" clause (in method declaration) included in C#?
# How do I check to see if a column name exists in a CachedRowSet?
# How do I fix "The expression of type List needs unchecked conversion...'?
# How to clone ArrayList and also clone its contents?
# How many JDBC connections in Java?
# How do I handle simultaneous key presses in Java?
# Is it possible to use a primitive type (int) in as a generic type in Java?
# Why will there be no native properties in Java 7?
# How to check if array element is null to avoid NullPointerException in Java
# How to generically specify a Serializable List
# Is it good practice to replace Class with Class<? extends Object> to avoid warnings?
# How does bytecode get verified in the JVM?
# Why does Java code with an inner class generates a third SomeClass$1.class file?
# How does Java pick which overloaded function to call?
# Why don't Java, C# and C++ have ranges?
# How to convert a Java object (bean) to key-value pairs (and vice versa)?
# How do I close a port in a case of program termination?
# How to set background image in Java?
# How do I find the caller of a method using stacktrace or reflection?
# Why doesn't java.util.Set have get(int index)?
# How to make the division of 2 ints produce a float instead of another int?
# How to check whether the elements of an ArrayList are all contained in another ArrayList
# How to find 1 or more partially intersecting time-intervals in a list of few million?
# How do I read input character-by-character in Java?
# How to sort search results on multiple fields using a weighting function?
# How can I implement a threaded UDP based server in Java?
# How to interrupt a BlockingQueue which is blocking on take()?
# How do you set the time and only the time in a calendar in Java?
# How do I compare classes using reflection?
# How do you find all subclasses of a given class in Java?
# Why doesn't Java allow generic subclasses of Throwable?
# Why doesn't Java have a copy constructor?
# Why is Java's Iterator not an Iterable?
# Why is the JVM slow to start?
# How to extract the file name from a file URI and create a link for the same?
# Why does autoboxing make some calls ambiguous in Java?
# Why is spawning threads in Java EE container discouraged?
# How to quickly find added / removed files?
# Is it OK to use == on enums in Java?
# Why do some claim that Java's implementation of generics is bad?
# How can I check if a single character appears in a string?
# Is it a good way to use java.util.concurrent.FutureTask?
# Why must delegation to a different constructor happen first in a Java constructor?
# How to enumerate IP addresses of all enabled NIC cards from Java?
# How do I address unchecked cast warnings?
# Why is compareTo on an Enum final in Java?
# Why does Math.floor return a double?
# How to debug ConcurrentModificationException?
# Why can't I define a static method in a Java interface?
# Why does C# not allow const and static on the same line?
# Is it wrong to have static and non-static methods in the same class?
# Why avoid the final keyword?
# How do I convert images between CMYK and RGB in ColdFusion (Java)?
# How do I compare strings in Java?
# How can I sort the keys of a Map in Java?
# How to create a generic array in Java?
# Why does java.util.Properties implement Map<Object,Object> and not Map<String,String>
# How can I pass a parameter to a Java Thread?
# How to use regular expressions to match everything before a certain type of word
# How to put the content of a ByteBuffer into an OutputStream?
# How to get the last 25 elements of a SortedSet?
# Why is super.super.method(); not allowed in Java?
# Why does an SWT Composite sometimes require a call to resize() to layout correctly?
# How do I use arrays of generic types correctly?
# How to determine an object's class?
# Why catch Exceptions in Java, when you can catch Throwables?
# How to Cache InputStream for Multiple Use
# How can I find all the methods that call a given method in Java?
# How to get audio data from a MP3?
# How do I fill arrays in Java?
# How to implement a most-recently-used cache
# How to get a unique key for two fields with Hibernate?
# How would you code an efficient Circular Buffer in Java or C#
# How to debug JNI/C library?
# How do I intercept a method invocation with standard java features (no AspectJ etc)?
# How to quote "*/" in JavaDocs
# How can I hide all java.lang.Object methods from code completion?
# How to check if a session is invalid
# Why isn't calling a static method by way of an instance an error for the Java compiler?
# How do synchronized static methods work in Java?
# How can I tell if a Java integer is null?
# How can I determine if a file is a PDF file?
# How to parse a currency Amount (US or EU) to float value in Java
# How do I launch a completely independent process from a Java program?
# How to explore which classes are loaded from which JARs?
# How to present the nullable primitive type int in Java?
# How to convert a Collection to List?
# How to replace a set of tokens in a Java String?
# Why no static methods in Interfaces, but static fields and inner classes OK? [pre-Java8]
# How to get an InputStream from a BufferedImage?
# Why can't we have static method in a (non-static) inner class?
# How to use ConcurrentLinkedQueue?
# How can I use the java for each loop with custom classes?
# How do I pipe the Java console output to a file?
# Why would one declare a Java interface method as abstract?
# Is it possible to reference a nested generic parameter in java?
# Why is there no GIL in the Java Virtual Machine? Why does Python need one so bad?
# How can I find out the serialVersionUID of a serialized Java object?
# How to suppress all checks for a file in Checkstyle?
# How to convert a byte array to its numeric value (Java)?
# How can I save a PNG with a tEXt or iTXt chunk from Java?
# How to use a bitwise operator to pass multiple Integer values into a function for Java?
# Why the awkward Design of System.out?
# Is it possible to extend a class with no constructors in Java?
# Why isn't my @BeforeClass method running?
# How to calculate the difference between two Java java.sql.Timestamps?
# How do I sort a Set to a List in Java?
# How can I make sure N threads run at roughly the same speed?
# Why won't this generic java code compile?
# How to analyze simple English sentences
# How to walk through Java class resources?
# How can I exchange the first and last characters of a string in Java?
# Why does the Java List interface not support getLast()?
# How can I handle an IOException which I know can never be thrown, in a safe and readable manner?
# How does synchronized work in Java
# How to get the last value of an ArrayList
# How to know if other threads have finished?
# How to read a single char from the console in Java (as the user types it)?
# Is it possible to make anonymous inner classes in Java static?
# How do you merge two input streams in Java?
# Why does reading a file into memory takes 4x the memory in Java?
# Why is Java's Class<T> generic?
# Is it good practice to use java.lang.String.intern()?
# How many threads can a Java VM support?
# How do I use the Java ClassLoader to load a file fromthe classpath?
# How can I cast a list using generics in Java?
# Why does this exceed the 65,535 byte limit in Java constructors and static Initializers?
# Why do inner classes make private methods accessible?
# How can I find repeated characters with a regex in Java?
# Why is javac 1.5 running so slowly compared with the Eclipse compiler?
# How to get a column from a 2D java array?
# How can I find the target Java version for a compiled class?
# How to send an iCal meeting request using Java Mail, and receive the response
# How do you format a fractional percentage with java.text.MessageFormat
# How to write javadoc links?
# How to determine the date one day prior to a given date in Java?
# How are weak references implemented?
# How can I check if a resource bundle key does not exist using JSTL tags?
# How does Java's Dynamic Proxy actually work?
# How can I replace a string in parentheses using a regex?
# How to save Chinese Characters to file with java?
# Why is the clone() method protected in java.lang.Object?
# How to replace tokens in a string without StringTokenizer
# How to add a timeout value when using Java's Runtime.exec()?
# Why shouldn't you extend JFrame and other components?
# Why is import of class not needed when calling method on instance (Java)
# How to convert an ArrayList containing Integers to primitive int array?
# How do I implement task prioritization using an ExecutorService in Java 5?
# Why C# implements methods as non-virtual by default?
# How to split a comma separated String while ignoring escaped commas?
# How to use URLClassLoader to load a *.class file?
# How to call Java functions from C++?
# How do you make your Java application memory efficient?
# How does the Java cast operator work?
# Why does parsing '23:00 PM' with SimpleDateFormat("hh:mm aa") return 11 a.m.?
# How to keep a single column from being reordered in a JTable?
# How can I safely encode a string in Java to use as a filename?
# Why can Haskell handle very large numbers easily?
# How to copy properties from one Java bean to another?
# Why String.indexOf do not use exception but return -1 when substring not found?
# How can I get a Future<MyObject> without using ExecutorService?
# How to execute system commands (linux/bsd) using Java
# Why is String's format(Object... args) defined as a static method?
# Why do regular expressions in Java and Perl act differently?
# Why would I care about IOExceptions when a file is closed?
# How to escape HTML special characters in Java?
# Why does the java.util.Set<V> interface not provide a get(Object o) method?
# Why are we getting ClosedByInterruptException from FileChannel.map in Java 1.6?
# Why does an hour get added on to java.util.Date for dates before Nov 1 1971?
# How does Terracotta work in this situation?
# How to know about OutOfMemory or StackOverflow errors ahead of time
# How to detect deadlock ? Timeout in synchronized block?
# Why all java methods are implicitly overridable?
# How can I have a Singleton that's derived from an abstract base type in Java?
# How do I declare and initialize an array in Java?
# How can you pipe an OutputStream to a StreamingDataHandler?
# Is it legal to call the start method twice on the same Thread?
# How does Java convert int into byte?
# How to use wait and notify in Java?
# How can I sort this ArrayList the way that I want?
# How can I calculate the difference between two ArrayLists?
# How to create a file in java (not a folder) ?
# How do I convert a String to Double in Java using a specific locale?
# Why are these == but not `equals()`?
# Why does Java have transient fields?
# Why do applets not need a main()?
# Why does Java BigDecimal return 1E+1?
# How to wait for a number of threads to complete?
# How to make a new List in Java
# How to find annotated methods in a given package?
# How to get multiple regex matches in Java?
# how to create an InputStream from a Document or Node
# How do you cast a List of supertypes to a List of subtypes?
# How do I copy DOM nodes from one document to another in Java?
# How Do I Clone A JAXB Object
# How do I encode/decode UTF-16LE byte arrays with a BOM?
# why is 24 * 60 * 60 * 1000 * 1000 divided by 24 * 60 * 60 * 1000 not equal to 1000 in Java?
# How should I extract compressed folders in java?
# How do I convert from int to Long in Java?
# Why does Java implicitly (without cast) convert a `long` to a `float`?
# How to determine main class at runtime in threaded java application?
# How are nested capturing groups numbered in regular expressions?
# Is it necessary to call a flush() (JPA interface) in this situation?
# How to access static resources when mapping a global front controller servlet on /*
# How do I find the physical memory size in Java?
# How do I match text within parentheses using regex?
# How does one manage object pooling in Spring?
# Why do I get "Exception; must be caught or declared to be thrown" when I try to compile my Java code?
# How can I use MATLAB arrays as keys to the HashMap java objects?
# How to get the unique ID of an object which overrides hashCode()?
# Why Use java.io.Console?
# how to find java classes?
# How are Java generics different from C++ templates? Why can't I use int as a parameter?
# How to tell which SHIFT key was pressed?
# Why is Multiple Inheritance not allowed in Java or C#?
# How do I set -Dfile.encoding within ant's build.xml?
# How do I make a thread wait for JFrame to close in Java?
# How to most elegantly iterate through parallel collections?
# Why does the "protected" modifier in Java allow access to other classes in same package?
# Is it possible to use RMI bidirectional between two classes?
# How to cast generic List types in java?
# How to pass a class object from Scala to Java?
# How to develop multi-touch applications in Java?
# How to initialize a ByteBuffer if you don't know how many bytes to allocate beforehand?
# How to serialize static data members of a Java class?
# How would one implement an FPS camera?
# How to convert nanoseconds to seconds using the TimeUnit enum?
# Is it better practice to use String.format over string Concatenation in Java?
# How to map collections in Dozer
# How to map enum in JNA
# How can I convert an Integer to localized month name in Java?
# Why is the Bigdecimal(double d) construction still around?
# How to track task execution statistics using an ExecutorService?
# How can I check if a Java program's input/output streams are connected to a terminal?
# How to convert object array to string array in Java
# Why is non-breaking space not a whitespace character in java?
# How to Serialize a list in java?
# How to convert a Map to List in Java?
# How to parse this string in Java?
# How to have 2 collections of the same type in JPA?
# Why should you have to dispose() a java.awt.Window that goes out of scope?
# Why do some languages need Boxing and Unboxing?
# How can I change the width of a JComboBox dropdown list?
# How do you draw a string centered vertically in Java?
# How can I code Java to allow SSE use and bounds-check elimination (or other advanced optimizations)?
# How can produce a DOCTYPE declaration with DOM level 3 serialization API?
# How to manage the game state in face of the EDT?
# How to handle StackOverflowError in Java?
# How to convert List<Integer> to int[] in Java?
# How to wrap lines in a jtable cell?
# How to use String as Velocity Template?
# How to strip whitespace-only text nodes from a DOM before serialization?
# How to keep the order of elements in hashtable
# How to get a Class Object from the Class Name in Java
# Why aren't variables in Java volatile by default?
# Why are data transfer objects (DTOs) an anti-pattern?
# How to determine if a String contains invalid encoded characters
# How to mock a String using mockito?
# Why passing {a, b, c} to a method doesn't work?
# How to access the Java method in a C++ application
# How to write a UTF-8 file with Java?
# How can I write custom Exceptions?
# How to send and receive serialized object in socket channel
# How can I require a generic parameter to be an enum that implements an interface?
# How to convert Rhino-JavaScript arrays to Java-Arrays
# How to start a background process in Java EE
# How to add one day to a date?
# Why do I get ClassNotPersistableException while running GWT App Engine application in hosted mode?
# How much memory does a Java object use when all its members are null?
# Why can't I retrieve an item from a HashSet without enumeration?
# How can I determine whether a Java class is abstract by reflection
# How can I catch all the exceptions that will be thrown through reading and writing a file?
# Is it possible to solve the "A generic array of T is created for a varargs parameter" compiler warning?
# How to split a path platform independent?
# How can I slice an ArrayList out of an ArrayList in Java?
# How does the JVM ensure that System.identityHashCode() will never change?
# How do I convert a MATLAB image processing program to java?
# How to monitor Java memory usage?
# How to create multi-language JavaDocs?
# How do I calculate someone's age in Java?
# How to avoid unchecked-conversion-warning in Java, if you use legacy libraries?
# How to convert int[] into List<Integer> in Java?
# How do I call some blocking method with a timeout in Java?
# How do I increase the number of displayed lines of a Java stack trace dump?
# Why must local variables, including primitives, always be initialized in Java?
# How to replace string only once without regex in Java?
# How is values() implemented for Java 6 enums?
# how to get the one entry from hashmap without iterating
# How do I display a date with a custom timezone?
# Why doesn't Java tell you which pointer is null?
# How to find the index of an element in an array in Java?
# Why is it not possible to extend annotations in Java?
# Why doesn't Bloch's Builder Pattern work in C#
# Why can an identifier not start with a number?
# How to create a zip file in Java
# How does Java implement hash tables?
# Is it possible to loop through a classes members in java?
# How do I print the class structures in a jar file using the javap tool?
# How do I say 5 seconds from now in Java?
# Why is String[] args required in Java?
# How can I lookup a Java enum from its String value?
# How to convert int[] to byte[]
# How to get vm arguments from inside of java application?
# How do I detect unicode characters in a Java string?
# How to mask a password in Java 5?
# How to declare and consume events in Java
# How do I find out if first character of a string is a number?
# How to convert an address from IPv4 to IPv6
# How do I convert Double[] to double[]?
# How to solve "java.io.IOException: error=12, Cannot allocate memory" calling Runtime#exec()?
# Why does 128==128 return false but 127==127 return true when converting to Integer wrappers?
# How can I test if an array contains a certain value?
# How to escape a square bracket for Pattern compilation
# Why is the Java date API (java.util.Date, .Calendar) such a mess?
# How to force a Java thread to close a thread-local database connection
# How to isolate your program from calls to a "bad" API?
# Is it bad practice to use an Enum's ordinal value to index an array in Java?
# How does semaphore work?
# Why is this Java array considered two dimensional?
# How can I invert the case of a String in Java?
# Why is an array not assignable to Iterable?
# How would you find out if a machine’s stack grows up or down in memory? (JAVA)
# Why InputStream and OutputStream implement Closeable and Socket doesn't?
# How to wait for all threads to finish, using ExecutorService?
# How do I find out what jar files are actually used when compiling a java project
# How do I convert an InputStream to a String in Java?
# How to make a J2ME application run in Background?
# How to analyze memory fragmentation in java?
# How many characters can a Java String have?
# How to redirect verbose garbage collection output to a file?
# How can I share memory between two JVM instances?
# how to garbage collect a direct buffer java
# How to append text to an existing file in Java
# How to read the value of a private field from a different class in Java?
# Why is preprocessor usage less common in languages other than C/C++/ObjC?
# Why Java ImageIO flattens JPEG colors
# How to improve the builder pattern?
# Why is it allowed to access Java private fields via reflection?
# How to ensure Java threads run on different cores
# Why can't I use foreach on Java Enumeration?
# How to encrypt String in Java
# Why do all Java Objects have wait() and notify() and does this cause a performance hit?
# How to shut down all Executors when quitting an application?
# Why is each public class in a separate file?
# How is an instance initializer different from a constructor?
# Is it worth mitigating against the effects of garbage collection?
# How does Java Graphics.drawImage() work and what is the role of ImageObserver
# Why is Java's boolean primitive size not defined?
# How to start an EJB Timer on deployment?
# How to Print Hexadecimal Numbers in PHP or Java
# How to compile a java source file which is encoded as "UTF-8"?
# How should I deal with a very large array in Java?
# How can I test final and static methods of a utility project?
# How to convert float to int with Java
# Why is List<Number> not a sub-type of List<Object>?
# How to make a Java class that implements one interface with two generic types?
# How can I dynamically look up a static class member in Clojure?
# How to create tmp file name with out creating file
# Why are there no concurrent collections in C#?
# Why can't I give different name to class than the file name?
# Why is Java's Double.compare(double, double) implemented the way it is?
# How to use Java property files?
# How to get a unique computer identifier in Java (like disk id or motherboard id)
# How is the java memory pool divided?
# How to Parse Negative Long in Hex in Java
# How can I take a heap dump on Java 5 without garbage collecting first?
# How to use an array constant in an annotation
# How much memory does a Hashtable use?
# How do I split an integer into 2 byte binary?
# How to efficiently (performance) remove many items from List in Java?
# How to get the current date and time of your timezone in Java?
# How can I create a password?
# how to check session has been expired in java?
# How do I print a list of strings contained within another list in iReport?
# How to compare almost similar Strings in Java? (String distance measure)
# How to reduce Scala (/ Java) startup overhead?
# How to use two numbers as a Map key
# How to prevent an object from getting garbage collected?
# How to find out why renameTo() failed?
# How to compare two Dates without the time portion?
# How to get the filename without the extension in Java?
# How can I find out if a File is a file or directory if it does not exist?
# How to do an Integer.parseInt() for a decimal number?
# How to really read text file from classpath in Java
# how to get data between quotes in java?
# How important are naming conventions for getters in Java?
# How do I detect whether the file system is case-sensitive?
# How can I generate pseudo-random "readable" strings in Java?
# Is it bad practice to make a setter return "this"?
# How to synchronize a static variable among threads running different instances of a class in java?
# Why is UncaughtExceptionHandler not called by ExecutorService?
# How can I parse a date including timezone with Joda Time
# How to kill deadlocked threads in Java?
# How does Integer.parseInt(string) actually work?
# Why can't reference to child Class object refer to the parent Class object?
# Is it possible in Java to check if objects fields are null and then add default value to all those attributes?
# How do I call java methods on an object from a FreeMarker template?
# Is it possible for Scala to have reified generics without changing the JVM?
# How can I determine the type of a generic field in Java?
# Why does JPA have a @Transient annotation?
# How is the == operator implemented in Java?
# Why no global variables in java like C++?
# How to throw a checked exception from a java thread?
# How to Generate Unique ID in Java (Integer)?
# Why this NumberFormatException?
# How do I sort a list by different parameters at different timed
# How to simulate the Out Of memory : Requested array size exceeds VM limit
# Why doesn't Java's main use a variable length argument list?
# Why not abstract fields?
# How to initialize an array in Java?
# How do you continuously read a file in Java?
# How large can an appengine task payload be?
# How to sort a treemap based on its values?
# How can I protect myself from a zip bomb?
# How to declare array elements volatile in Java?
# How using BigDecimal would affect application performance?
# How can i use JSTL variable in scriptlet?
# Why this is not compiling in Java?
# How can I check if an InputStream is empty without reading from it?
# How to parse a JSON and turn its values into an Array?
# Why does Double.NaN equal itself when wrapped in a Double instance?
# How to test for equality of complex object graphs?
# Why is list.size()>0 slower than list.isEmpty() in Java?
# How to convert String object to Boolean Object?
# How do I do a deep copy of a 2d array in Java?
# Why can I access my private variables of the "other" object directly, in my equals(Object o) method
# How to Solve Equations with java?
# is it possible to overload a final method
# How to properly trim whitespaces from a string in Java?
# Why did Sun specify String.hashCode() implementation?
# How to find the number of objects in the heap
# How do you test to see if a double is equal to NaN?
# how to create a file in Java only if one doesn't already exist?
# Why is Java Vector class considered obsolete or deprecated?
# How to monitor progress (JProgressBar) with FileChannels transferFrom() method?
# Is it possible to make an operating system using java?
# How to know when there's too much logging messages?
# How to find, with Java, if a certain font is installed correctly on a machine
# Why can't a Generic type containing a Generic type be assigned to a Generic typed class of wildcard type
# Why throwing an EJBException is a "recommended" practice?
# Why can't you reduce the visibility of a method in a Java subclass?
# How does "this" escape the constructor in Java?
# Why does this compile?
# Why is JavaMail Transport.send() a static method?
# How can I parse a HTML string in Java?
# Why doesn't the JVM cache JIT compiled code?
# How to make a folder hidden using java
# Why is an "L" getting added to my Java path?
# Why are all fields in an interface implicitly static and final?
# How do you return a JSON object from a Java Servlet
# How can I make my AES encryption identical between Java and Objective-C (iPhone)?
# How to convert array of floats to array of doubles in Java?
# Is it unnecessary to put super() in constructor?
# How to sort nearly sorted array in the fastest time possible? (Java)
# Why Java OutputStream.write() Takes Integer but Writes Bytes
# How can I reference my Java Enum without specifying its type
# Why is String class declared final in Java?
# Why is paint()/paintComponent() never called?
# why autoimport only java.lang package?
# How to properly catch RuntimeExceptions from Executors?
# Why is there a method iterator() on java.util.Collection
# How do I create a Java sandbox?
# Why java has "String" type and not "string"?
# how to choose the jvm heap size?
# How can I convert a stack trace to a string?
# How to implement Java 256-bit AES encryption with CBC
# How to access a Runnable object by Thread?
# Why does Executors.newCachedThreadPool throw java.util.concurrent.RejectedExecutionException during submit
# How to iterate an ArrayList inside a HashMap using JSTL?
# How to read XMI?
# How should I throw a divide by zero exception in Java without actually dividing by zero?
# How to determine field-type for SOLR indexing?
# How to @link to a Enum Value using Javadoc
# Why is the JVM not platform independent, given that Java (the language) is platform independent?
# Why can't a Java class be declared as static?
# How do I stop a Java library from printing to the console?
# How do I get a Double out of a resultset instead of double?
# why iterator.remove() has been described as optional operation?
# How is generic function implemented in java?
# How java.io.Buffer* stream differs from normal streams?
# how to convert byte array to string and vice versa
# How to Increment a class Integer references value in java from another method
# How can I measure the speed of code written in Java? (AI algorithms)
# How to analyse a NoClassDefFoundError caused by an ignored ExceptionInInitializerError?
# How to invoke a method in java using reflection
# How does reflection affect Perm size?
# Is it problematic to assign a new value to a method parameter?
# Is it better to use try/catch instead of multiple IF statements?
# How to determine an incoming connection is from local machine
# How to recover a RSA public key from a byte[] array?
# Why are there finalizers in java and c#?
# Why is "java.lang.OutOfMemoryError: Java heap space" not caught?
# How to add reference to a method parameter in javadoc?
# Is it possible to hide or lower access to Inherited Methods in Java?
# Why doesn't changing the pre to the post increment at the iteration part of a for loop make a difference?
# How to determine by reflection if a Method returns 'void'
# Why is it bad practice to call System.gc()?
# How to convince management that reformatting the entire Java code base is safe
# How to get the current time in YYYY-MM-DD HH:MI:Sec.Millisecond format in Java?
# Why should I care that Java doesn't have reified generics?
# How is hashCode() calculated in Java
# How to play .wav files with java
# How to pass a type as a method parameter in Java
# How to decode encoded special XML characters in a string?
# Why does using a default-valued Java Integer result in a NullPointerException?
# How to replace ï¿½ in a string
# Why do you name the class twice during instantiation in Java?
# How to write a Java-enum-like class with multiple data fields in C++?
# How do I generate a random integer between min and max in java?
# How do I make my ArrayList Thread-Safe? Another approach to problem in Java?
# How to read pixel color in a java BufferedImage with transparency
# How to call an Oracle function from Hibernate with a return parameter?
# How can Java inline over virtual function boundaries?
# How can I get the actual error behind HttpResponseException?
# How to obtain all subsequence combinations of a String (in Java, or C++ etc)
# Why doesn't Java support generic Throwables?
# How to set the maximum memory usage for JVM?
# How to Find the Default Charset/Encoding in Java?
# How to reinterpret the bits of a float as an int
# how to get the min and max heap size settings of a JVM from within a Java program
# Why are wait() and notify() declared in Java's Object class?
# How to sort a Collection<T>?
# How to tell if a Java class is abstract?
# How to read a file from a jar file?
# How to get the capacity of the ArrayList in Java?
# Why can Java Collections not directly store Primitives types?
# Why does the Java compiler not like primitive int as type for values in HashMap?
# How can I require a method argument in Java to implement multiple interfaces?
# Why does this data YYYY-MM-DD regex fail in Java?
# How safe is my safe rethrow?
# How should I generate an initialization vector?
# How do I make a Class extend Observable when it has extended another class too?
# How many times can classes be nested within a class?
# How to force Java to throw arithmetic exception?
# Why do Java programmers like to name a variable "clazz"?
# Why does the xor operator on two bytes produce an int?
# How to unit test that ExecutorService spawns new thread for task?
# Is it wrong to make every concrete class to inherit from an interface?
# How to merge two java.util.Properties objects?
# Why can outer Java classes access inner class private members?
# How can I iterate through the unicode codepoints of a Java String?
# How do I sort enum members alphabetically in Java?
# Why is Java's AbstractList's removeRange() method protected?
# Why is the finalize() method in java.lang.Object "protected"?
# How to read input with multiple lines in Java
# How do I find out which JAXP implementation is in use and where it was loaded from?
# How to free up memory?
# Is it possible to do computation before super() in the constructor?
# How can I add business days to the current date in Java?
# how to find and return objects in java hashset
# How to display an output of float data with 2 decimal places in Java?
# How do I check if a file exists in Java?
# How to quickly determine if a method is overridden in Java
# How to free memory in Java?
# Why are not all type information erased in Java at runtime?
# How to check if String value is Boolean type in Java?
# How do you map a "Map" in hibernate using annotations?
# How do I get the first n characters of a string without checking the size or going out of bounds?
# How to round *down* integers in Java?
# How to limit speed with BMW JSDK on 116i programmatically from Java?
# How to sort 100GB worth of strings
# How to convert InputStream to FileInputStream
# How to read all files in a folder from Java?
# How do I pass console input to a running Java program instead of to jdb?
# Why is PermGen space growing?
# Why do I get a NullPointerException when comparing a String with null?
# How to read a file into string in java?
# How do you replace double quotes with a blank space in Java?
# How do I find the last modified file in a directory in Java?
# How to supply value to an annotation from a Constant java
# Why make Abstract classes and Interfaces?
# Why doesn't Java allow to throw a checked exception from static initialization block?
# Why java has fixed data type size unlike C
# Why doesn't Java throw an Exception when dividing by 0.0?
# Why not allow an external interface to provide hashCode/equals for a HashMap?
# How can I solve the Log Pile wooden puzzle with a computer program?
# How can I initialize a String array with length 0 in Java?
# How to capitalize the first character of each word in a string
# How to use Sets as keys in Java Maps
# Why would you catch InterruptedException to call Thread.currentThread.interrupt()?
# Why are synchronize expensive in Java?
# How to set constraints on generic types in Java?
# Why it could not find the main class?
# How to lock a java method to protect multiple invocations
# how to use "tab space" while writing in text file
# How to get the Array Class for a given Class in Java?
# How to parse Date from HTTP Last-Modified header?
# Why can final object be modified?
# How to create a Java class, similar to a C++ template class?
# why does a return statement inside a try catch work with 'throws'
# How to implement hashCode and equals method
# How can I convert a Java HashSet<Integer> to a primitive int array?
# Why can I "fake" the stack trace of an exception in Java?
# how to send through ServletOutputStream characters in UTF-8 encoding
# How do I create an input stream from a ZipEntry
# How to print bytes in hexadecimal using System.out.println?
# How to cast a double to an int in Java by rounding it down?
# How do I iterate over class members?
# How to handle a static final field initializer that throws checked exception
# How to dynamically monitor Java heap size?
# How to intentionally cause a custom java compiler warning message?
# Why can't I split a string with the dollar sign?
# How to store a large (10 digits) integer?
# How to make ThreadPoolExecutor's submit() method block if it is saturated?
# How to encapsulate an array in Java
# How do I avoid repetition in Java ResourceBundle strings?
# How do I use paramertized generic types in an inner class?
# How to limit setAccessible to only "legitimate" uses?
# How do I format a long integer as a string without separator in Java?
# How a thread should close itself in Java?
# Why boolean in Java takes only true or false? Why not 1 or 0 also?
# How to write console output to a txt file
# How does Java efficiently search jar files for classes?
# Why reduce the size of the Java JVM thread stack?
# How can I write a byte array to a file in Java?
# Why does Java read its default settings from the system
# How to quit a java app from within the program
# How to compare two maps by their values
# What to do when Java Best Practices conflict with Mockito
# How do I measure time elapsed in Java?
# How to find an available port?
# How can I get a Unicode character's code?
# How does Java List size() work?
# How to create a class literal of a known type: Class<List<String>>
# How to get Locale from its String representation in Java?
# How to draw a directed arrow line in Java?
# How do determine if an object is locked (synchronized) so not to block in Java?
# How to parse month full form string using DateFormat in Java?
# Why classes compile to .class but interface does not to .interface
# How can I inherit the system's anti-alias setting for painting text to off-screen images like swing does?
# How to convert a JSON string to a Map<String, String> with Jackson JSON
# how to print a Double without commas
# How does volatile actually work?
# Why does Arrays.sort take Object[] rather than Comparable[]?
# Why are dates calculated from January 1st, 1970?
# How to check if a given Regex is valid?
# Why does a HashMap rehash the hashcode supplied by the key object?
# ...
# Why a surrogate java regexp finds hypen-minus -
# Why is String concatenation faster than String.valueOf for converting an Integer to a String?
# Is it bad practice to make generic arrays, and what would be the alternative?
# Why does .class not invoke the static block in a Class?
# Why does Java require an explicit cast on a final variable if it was copied from an array?
# Why must throw statements be enclosed with a full code block in a lambda body?
# How do I convert lambda parameters to usable objects?
# Why Stream<T> collect method returns different key order?
# How to wrap checked exceptions but keep the original runtime exceptions in Java
# How to use retrofit as a singleton while using gson convertor?
# How to reuse application of filter & map on a Stream?
# How can I avoid creating useless pass-through constructors in child classes just to pass arguments to "super()"?
# Why Matcher.group throwing IndexOutOfBoundsException Exception
# How to sum BigDecimal properties of objects in Java8 lambda expression?
# How to match the middle character in a string with regex?
# Why does this Kotlin method have enclosing backticks?
# Is it a bad practice to add elements to List using getter method in java?
# How to save List<Object> to SharedPreferences?
# How to get the key in Collectors.toMap merge function?
# Why exception is null in ThreadPoolExecutor's afterExecute()?
# How to correctly find the stream characteristics in Java-8?
# How to get a custom type instead of Integer when using Collectors.summingInt?
# Why doesn't add(String) on a List<Integer> passed to a List parameter throw an exception?
# Why is adding an OnClickListener inside onBindViewHolder of a RecyclerView.Adapter considered bad practice?
# How to convert an Optional<T> into a Stream<T>?
# How to sort Integer digits in ascending order without Strings or Arrays?
# How to copy HashMap (not shallow copy) in Java
# How to skip specific element in SimpleXML
# How to replace 'if statement' with rx-java for avoiding callback hell?
# How to filter out only the first element not matching a predicate in a Java sequential Stream?
# Why does parseInt warn of using valueOf
# Why isn't Math.nextAfter(Double.MAX_VALUE, 1) equal to Double.INFINITY?
# Why doesn't Stream.limit work as expected in this snippet?
# Why clone() is the best way for copying arrays?
# How to implement a NumberField in javaFX 2.0?
# How to hide warning "Illegal reflective access" in java 9 without JVM argument?
# Why shouldn't Java enum literals be able to have generic type parameters?
# Why does if(Boolean.TRUE) {...} and if(true) {...} work differently in Java
# How to get current year in android?
# How to increase maximum number of JVM threads (Linux 64bit)
# How to add Menus and SubMenus recursively in JavaFX?
# How to reference a generic parameter recursively?
# Why does a method reference to ctor that "throws" ... throw as well?
# Why is DataFetcher not called in this GraphQL setup?
# How to validate that a Java 8 Stream has two specific elements in it?
# Why is int implicitly cast to float rather than double when invoking constructor?
# Why does counting to 2^24 execute quickly, but counting to 2^25 take much longer?
# How is it possible that StringBuilder.setLength(0) invokes Arrays.fill?
# Why does this code run faster with a lock?
# How do I avoid NullPointerExceptions in lambda comparators?
# Why is this java Stream operated upon twice?
# How do I use a delimiter in Java Scanner?
# Why context is static in this Java 8 stream example?
# How to parse JSON in Kotlin?
# Why doesn't Java close() stream after a terminal operation is issued?
# How to access type annotations on a receiver type's parameters
# How to sort some elements and leave others in Java?
# Why doesn't this statement throw a StackOverflowError?
# How to efficiently store small byte arrays in Java?
# Why can't Stream.flatMap accept a collection?
# How to format a ZonedDateTime to a String?
# Is it possible to use XOR to detect if exactly one of multiple conditions is true?
# Why is processing a sorted array *slower* than an unsorted array? (Java's ArrayList.indexOf)
# How to sort recylerview by lowest number / String android studio
# Why during autoboxing final long to Byte compilation error happens, but final int to Byte is ok?
# How to define a member interface in a static context in java?
# How a lambda expression maps into a functional interface?
# How can solve JSON column in H2
# How do I program monadicaly in Java8 while getting comparable performance?
# How to test the identity and an associativity constraints of a java-8 custom Collector
# How do I concisely write a || b where a and b are Optional values?
# How does integer type cast behave in Java for numbers beyond the range of integers?
# Why am I getting a NoClassDefFoundError exception rather than a StackOverflow error?
# Why does static field self assignment compile only with explicit static syntax?
# How can I create a Stream<String[]> with only one element with Stream.of?
# Is it a bug that Java 8's HashMap misbehaves if the keys implement Comparable in a way that isn't consistent with equals?
# How to implement finalize() in kotlin?
# Why does assigning short to byte only work when the short is final?
# How to connect to Password protected SQLite DB with OrmLite?
# How do I write a restful web service that accepts a binary file (pdf)
# How generics in java works for the following program?
# Why does this code, written backwards, print "Hello World!"
# How to compare LocalDate instances Java 8
# How to optimize Tomcat for Feed pull
# How to get a thread submitted to executer service and interrupt it in Java
# How to implement this Java interface in Kotlin?
# How to execute logic on Optional if not present?
# Why should I use an interface when there is only one implementation class?
# Why does this Java 8 lambda fail to compile?
# How to compare equality of lists of arrays with modern Java?
# Why does Object.hashCode() return the same value across runs
# How to pass an array of primitives as varargs?
# How to get ordered stream from a list in reverse order in Java 8
# How to stop and resume Observable.interval emiting ticks
# Why is Java 8 Optional implemented as final, without Some and None hierarchy?
# How to avoid 'instanceof' when implementing factory design pattern?
# How does index*int in a for loop end up with zero as result?
# why Exception or Error not generated when no main method found?
# How to bound the class type of the subclass
# Why can't I have a catch for a checked exception for a call that throws a generic?
# Why is (a*b != 0) faster than (a != 0 && b != 0) in Java?
# Is it possible to determine programmatically whether a file move will result in a copy?
# How do I sum the double values of a map stream in streamex?
# Why don't we need volatile with StampedLock?
# Why does bit-wise shift left return different results in Python and Java?
# How many requests can a java UDP socket handle?
# Why doesn't this code throw a ConcurrentModificationException?
# How would I make this Java 7 compatible?
# How to copy an iterator to another one?
# Why the maximum array size of ArrayList is Integer.MAX_VALUE - 8?
# Why does restricting GC to 1 thread increase performance?
# How to alter the design so that entities don't use injections?
# How to create instance of subclass with constructor from super class
# Why isn't Array.newInstance(Class<?>, int) generic?
# Why does \R behave differently in regular expressions between Java 8 and Java 9?
# Why does DecimalFormat ".#" and "0.#" have different results on 23.0?
# How to concatenate 2 or more strings as one inside a string array in Java?
# Why does the JVM require warmup?
# why the reference don't put into reference queue when finalize method overrided
# How are lazy streams implemented in Java 8?
# How to create a int[] or a Collection<Integer> with the value 0,1,2,...,N in one line in Java using lambda expression?
# How can I sort Arrays in a Collection?
# Why do we always type cast in Android/Java?
# Why does BufferedInputStream copy a field to a local variable rather than use the field directly
# Why does the Java 8 generic type inference pick this overload?
# How to create a map with Java stream API using a value outside the stream?
# Why can an instance of a class access private fields of another instance of its own type?
# Why does HALF_UP sometimes round down with double?
# Why use a wild card capture helper method?
# How to test all combinations of bad parameters?
# Why does variable initialization of to an assignment expression [String x = (x = y)] compile?
# How to calculate the number of days in a period?
# Why is static final slower than a new on each iteration
# Why does this generic code compile in java 8?
# Is it good practice to often use instanceof?
# Why is package visibility given priority over subclass visibility?
# How to access Kotlin companion object in Java?
# How can I create a general purpose paging spliterator?
# Why is Thread not an abstract class and start() not final?
# How can I refer to implementations of a method in annotation processing?
# How to get recognition of Java URI hashCode() bug that has been inappropriately denied
# how to find all possible solutions to a formula, like 100*7-8*3+7? (8 Out of 10 Cats Does Countdown solver)
# Why can I assign an integer literal to a short type variable but not to a short type method parameter?
# How to perform nested 'if' statements using Java 8/lambda?
# Why is passing two string arguments more efficient than one list argument
# How can I get the "current" IANA time zone abbreviation throughout time in ICU4J?
# How to implement the builder pattern in Java 8?
# Why does Gson serializes runtime type in list, not specified compile-time type?
# How can I construct a Locale with a custom first day of week?
# Why is there such a big difference on time between first nanoTime() call and the successive calls?
# Why this converter needs casting?
# Why does the equals() implementation generated by Eclipse check for null before type checking (instanceof)?
# How to convert List<V> into Map<K, List<V>>, with Java 8 streams and custom List and Map suppliers?
# Why Invalid conversion requested ERROR CODE: 17132?
# Why does the ExecutorService interface not implement AutoCloseable?
# Why Doesn't Java 8 Type Inference Consider Exceptions Thrown by Lambdas in Overload Selection?
# Why does Collections.sort use Mergesort but Arrays.sort does not?
# How does RxJava doOnError and onErrorReturn work?
# Why does Enumeration get converted to ArrayList and not List in java.utils?
# Why does the following code sort the List of objects?
# Why does the JVM have a maximum inline depth?
# How to get words average length using Lambda Expression
# How can I manually describe an example input for a java @RequestBody Map<String, String>?
# Is it possible to parse dates with both TextStyle.SHORT and TextStyle.FULL for the month?
# How to get annotations of a Kotlin property from Java?
# why BufferedReader.readLine can read a line which doesn't have a line separator
# How to filter a map by its values in Java 8?
# How to identify date from a string in Java
# How to check if a message has a combined character in it?
# How to count speed based on steps
# How to separate a List by a condition using Java 8 streams
# Why isn't there an Interface for something that provides a Stream<E>?
# Why can I only read 1024 bytes at a time with ObjectInputStream?
# Why is the StringBuilder chaining pattern sb.append(x).append(y) faster than regular sb.append(x); sb.append(y)?
# Why attempt to print uninitialized variable does not always result in an error message
# Why does invokeLater execute in the main thread?
# How to use the 'svm_toy' Applet example in LibSVM?
# Why do I get `java.lang.NoClassDefFoundError: scala/Function1` when I run my code in ScalaIDE?
# Why is ClassLoader's cache checked in ascending sequence?
# Why is logarithm slower in Rust than in Java?
# Why does storing a long string cause an OOM error but a breaking it into a list of short strings does not?
# Why does Java 8 DateTimeFormatter allows an incorrect month value in ResolverStyle.STRICT mode?
# How to validate Google receipt validation locally with old Order ID format?
# How to compose Closeable objects in Java?
# Why Deletion between start and end strings won't work properly in java?
# How to mock method call and return value without running the method?
# How do I schedule a task to run once?
# Why is Files.list() parallel stream performing so much slower than using Collection.parallelStream()?
# How to manage exceptions thrown in filters in Spring?
# Why 'T.super.toString()' and 'super::toString' use a synthetic accessor method?
# Why does the constructor of TreeSet<E> accept the parameter super of E instead of extend of E
# Is it possible to match nested brackets with regex without using recursion or balancing groups?
# Why can "return" return a "return" in Kotlin?
# Why is sub class' static code getting executed?
# Why "Numeric overflow in expression" warning occurs
# How to limit in groupBy java stream
# Why does the hashCode() of an ArrayList change every time you add a new element?
# How do I inherit KDoc documentation?
# How to efficiently compute the maximum value of a collection after applying some function
# How to determine the max precision for double
# How do I find the nearest common superclass of two non-interface classes
# Why isn't ReadWriteLock upgrade allowed?
# How to convert java.util.stream.Stream<Something> into kotlin.Sequence<Something>
# How to find out if a class is immutable
# Why doesn't Stream#reduce implicitly accept an accumulative function handling super type elements?
# Why do `java.time.ZoneOffset` instances sort 'backwards'?
# Why can't a class extend a static nested class occurring within it?
# how to replace anonymous with lambda in java
# Why are annotation string values not interned?
# Why is there no "List.reverse()" method in Java?
# How does the JVM reuse interned String substrings?
# Why can nested child classes access private members of their parent class, but grandchildren cannot?
# How to determine where method was called
# How does Scala distinguish between () => T and => T
# How to finalize SunPKCS11 Provider after it is initialized?
# How to convert a kotlin source file to a java source file
# Why does the narrowing conversion from int to short not work if local variable is used in the ternary operator
# How to compare two Collections for "equivalence" based on fields from different Java classes?
# Why is there a "d" in the definition of Double.NaN = 0.0d / 0.0?
# How to map a nested value to a property using Jackson annotations?
# How to throttle writes request to cassandra when working with "executeAsync"?
# Why is BitSet not Iterable?
# How to list all properties exposed by a Java class and its ancestors in Eclipse?
# Why does (boolean ^ int > 0) work?
# How do I refactor this loop?
# How to avoid a useless return in a Java method
# Why does using raw type variables affect signatures without reference to type-parameters?
# Why is this GoLang solution faster then the equivalent Java Solution?
# Why does this method reference assignment compile?
# Why is an ArrayList of ArrayLists not multidimensional?
# How to instantiate a generic recursive class in Java
# How to suitably compose Predicate and Function in a Java function?
# How to pass a getter as lambda function?
# Why is shared mutability bad?
# How do you properly synchronize threads on the native side of a JNI environment?
# Why does java stream.count() return a long?
# How do I use j2html without rendering everything
# How can I get a random number in Kotlin?
# How to write the clear() method in the list data structure?
# How to match stream elements but return false if non exists?
# Why does the JVM use giant int[] of all 0's?
# How do I run tests compiling a kotlin file in memory and check the result?
# How to generate random values where a percentage of them are 0?
# How to launch a Java program with precisely controlled execution time?
# How to sum the values in List<int[]> using Java 8
# How are coroutines implemented in JVM langs without JVM support?
# How to apply Filtering on groupBy in java streams
# How to use Java 8 Optionals, performing an action if all three are present?
# How to join two Optional<String> with a delimiter in Java 8
